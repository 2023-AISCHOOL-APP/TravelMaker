# %%
# !pip install xmltodict

# %%
import requests
import json
import xmltodict
import pandas as pd

# %%
# 지역기반 관광정보 조회

url = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=2'
data_xml = requests.get(url).text
dictionary = xmltodict.parse(data_xml)
data_json = json.loads(json.dumps(dictionary) )
data = data_json['response']['body']['items']['item']
df = pd.DataFrame(data)

# %% [markdown]
# 서울	1
# 인천	2
# 대전	3
# 대구	4
# 광주	5
# 부산	6
# 울산	7
# 세종	8
# 경기	31
# 강원	32
# 충북	33
# 충나	34
# 경북	35
# 경남	36
# 전북	37
# 전남	38
# 제주	39

# %%
df['contentid']

# %%
# 공통정보조회 contentid 
url2 = 'https://apis.data.go.kr/B551011/KorService1/detailCommon1?MobileOS=ETC&MobileApp=AppTest&_type=XML&contentId=2767573&contentTypeId=12&defaultYN=Y&firstImageYN=Y&areacodeYN=Y&catcodeYN=Y&addrinfoYN=Y&mapinfoYN=Y&overviewYN=Y&numOfRows=100&pageNo=1&serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D'
data_xml2 = requests.get(url2).text
dictionary2 = xmltodict.parse(data_xml2)
data_json2 = json.loads(json.dumps(dictionary2) )
data2 = data_json2['response']['body']['items']['item']
data2

# %%
data2

# %% [markdown]
# ## 서울

# %%
# 서울

seoul = []
url_seoul = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=1'
data_xml_seoul = requests.get(url_seoul).text
dictionary_seoul = xmltodict.parse(data_xml_seoul)
data_json_seoul = json.loads(json.dumps(dictionary_seoul) )
data_seoul = data_json_seoul['response']['body']['items']['item']
df_seoul = pd.DataFrame(data_seoul)

# %%
df_seoul

# %%
len(df_seoul['contentid'])

# %%
# 공통정보조회 contentid 
for i in range(len(df_seoul['contentid'])):
    try:
        url2 = f"https://apis.data.go.kr/B551011/KorService1/detailCommon1?MobileOS=ETC&MobileApp=AppTest&_type=XML&contentId={df_seoul['contentid'][i]}&contentTypeId=12&defaultYN=Y&firstImageYN=Y&areacodeYN=Y&catcodeYN=Y&addrinfoYN=Y&mapinfoYN=Y&overviewYN=Y&numOfRows=100&pageNo=1&serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D"
        data_xml2 = requests.get(url2).text
        dictionary2 = xmltodict.parse(data_xml2)
        data_json2 = json.loads(json.dumps(dictionary2) )
        data2 = data_json2['response']['body']['items']['item']
        seoul.append(data2)
    except:
        pass

# %%
seoul_df = pd.DataFrame(seoul)
seoul_df

# %%
title_seoul=seoul_df['title']
image_seoul=seoul_df['firstimage']
mapxy_seoul=seoul_df.loc[:,'mapx':'mapy']
overview_seoul=seoul_df['overview']
addr_seoul = seoul_df['addr1']
seoulDf = pd.concat([title_seoul,addr_seoul,overview_seoul,mapxy_seoul,image_seoul],axis=1)

# %%
seoulDf

# %%
seoulDf.to_csv('서울관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 인천

# %%
# 인천

inchon = []
url_inchon = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=2'
data_xml_inchon = requests.get(url_inchon).text
dictionary_inchon = xmltodict.parse(data_xml_inchon)
data_json_inchon = json.loads(json.dumps(dictionary_inchon) )
data_inchon = data_json_inchon['response']['body']['items']['item']
df_inchon = pd.DataFrame(data_inchon)

# %%
df_inchon

# %%
len(df_inchon)

# %%
# 공통정보조회 contentid 
for i in range(len(df_inchon['contentid'])):
    try:
        url2 = f"https://apis.data.go.kr/B551011/KorService1/detailCommon1?MobileOS=ETC&MobileApp=AppTest&_type=XML&contentId={df_inchon['contentid'][i]}&contentTypeId=12&defaultYN=Y&firstImageYN=Y&areacodeYN=Y&catcodeYN=Y&addrinfoYN=Y&mapinfoYN=Y&overviewYN=Y&numOfRows=100&pageNo=1&serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D"
        data_xml2 = requests.get(url2).text
        dictionary2 = xmltodict.parse(data_xml2)
        data_json2 = json.loads(json.dumps(dictionary2) )
        data2 = data_json2['response']['body']['items']['item']
        inchon.append(data2)
    except:
        pass

# %%
inchon_df = pd.DataFrame(inchon)
inchon_df

# %%
title_inchon=inchon_df['title']
image_inchon=inchon_df['firstimage']
mapxy_inchon=inchon_df.loc[:,'mapx':'mapy']
overview_inchon=inchon_df['overview']
addr_inchon = inchon_df['addr1']
inchonDf = pd.concat([title_inchon,addr_inchon,overview_inchon,mapxy_inchon,image_inchon],axis=1)

# %%
inchonDf

# %%
inchonDf.to_csv('인천관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 대전

# %%
# 대전

daejeon = []
# 공공데이터 포털에서 지역기반 관광지 데이터 가져오기(XML)
url_daejeon = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=3'
data_xml_daejeon = requests.get(url_daejeon).text
# XML형식을 json 으로 바꿔주기
dictionary_daejeon = xmltodict.parse(data_xml_daejeon)
data_json_daejeon = json.loads(json.dumps(dictionary_daejeon) )
# 변환한 json 파일에서 필요한 데이터부분을 가져와서 데이터프레임 시키기
data_daejeon = data_json_daejeon['response']['body']['items']['item']
df_daejeon = pd.DataFrame(data_daejeon)

# %%
df_daejeon
# Out:
#                         addr1  addr2 areacode booktour cat1   cat2       cat3  \
# 0               대전광역시 유성구 대학로  (구성동)        3        0  A01  A0101  A01011800
# 1       대전광역시 유성구 학하서로63번길 26  (계산동)        3        0  A02  A0201  A02010800
# 2            대전광역시 서구 괴곡동 963   None        3        0  A01  A0102  A01020100
# 3          대전광역시 서구 상보안윗길 160   None        3        0  A01  A0101  A01010400
# 4       대전광역시 유성구 과학로 169-148  (어은동)        3        0  A02  A0204  A02040800
# ..                        ...    ...      ...      ...  ...    ...        ...
# 127  대전광역시 대덕구 대전로1397번안길 126  (읍내동)        3        0  A02  A0201  A02010700
# 128  대전광역시 대덕구 대전로1397번안길 126  (읍내동)        3        0  A02  A0201  A02010700
# 129           대전광역시 서구 물안길 71  (흑석동)        3        0  A02  A0202  A02020700
# 130         대전광역시 유성구 가정로 218   None        3        0  A02  A0204  A02040800
# 131  대전광역시 대덕구 신탄진로756번안길 223  (용호동)        3        0  A02  A0204  A02040800
#
# ...

# %%
# 대전 상세내용 가져오기
daejeon_summary = pd.read_csv('대전overview.csv',encoding='utf-8')

# %%
# df_daejeon 데이터 프레임에서 이름, 주소, 경도, 위도, 이미지주소 가져와서 concat 해주기
addr_daejeon = df_daejeon['addr1']
title_daejeon = df_daejeon['title']
mapxxy_daejeon = df_daejeon.loc[:,'mapx':'mapy']
image_daejeon = df_daejeon['firstimage']

daejeonDf = pd.concat([title_daejeon,addr_daejeon,mapxxy_daejeon,image_daejeon], axis=1)

# %%
# concat 해준 데이터프레임과 상세내용 병합하기
daejeon_tour = pd.merge(daejeonDf,daejeon_summary)

# %%
# 파일로 저장하기
daejeon_tour.to_csv('대전관광지.csv',encoding='utf-8')

# %%
daejeonDf
# Out:
#             title                     addr1            mapx           mapy  \
# 0              갑천             대전광역시 유성구 대학로  127.3686912472  36.3674994928
# 1             광수사     대전광역시 유성구 학하서로63번길 26  127.2980482439  36.3425316541
# 2        괴곡동 느티나무          대전광역시 서구 괴곡동 963  127.3543169514  36.2863418541
# 3         구봉산(대전)        대전광역시 서구 상보안윗길 160  127.3394516798  36.2838835386
# 4        국가핵융합연구소     대전광역시 유성구 과학로 169-148  127.3541229552  36.3730597095
# ..            ...                       ...             ...            ...
# 127          회덕향교  대전광역시 대덕구 대전로1397번안길 126  127.4215110682  36.3842012982
# 128      회덕향교 대성전  대전광역시 대덕구 대전로1397번안길 126  127.4215166313  36.3839096653
# 129         흑석유원지           대전광역시 서구 물안길 71  127.3400883221  36.2620860417
# 130  ETRI 정보통신전시관         대전광역시 유성구 가정로 218  127.3652244796  36.3826476980
# 131    It's 수 홍보관  대전광역시 대덕구 신탄진로756번안길 223  127.4450712367  36.4433088410
#
#                                             firstimage
# ...

# %% [markdown]
# ## 대구

# %%
daegu = []
url_daegu = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=4'
data_xml_daegu = requests.get(url_daegu).text
dictionary_daegu = xmltodict.parse(data_xml_daegu)
data_json_daegu = json.loads(json.dumps(dictionary_daegu) )
data_daegu = data_json_daegu['response']['body']['items']['item']
df_daegu = pd.DataFrame(data_daegu)

# %%
df_daegu
# Out:
#                         addr1  addr2 areacode booktour cat1   cat2       cat3  \
# 0      대구광역시 달성군 가창면 가창로 1099  (가창면)        4        0  A02  A0203  A02030400
# 1          대구광역시 서구 서대구로3길 43  (내당동)        4        0  A02  A0202  A02020700
# 2       대구광역시 달성군 다사읍 강정본길 57   None        4        0  A02  A0202  A02020700
# 3          대구광역시 동구 옻골로 195-3  (둔산동)        4        0  A02  A0201  A02010400
# 4           대구광역시 중구 경상감영길 99  (포정동)        4        0  A02  A0202  A02020700
# ..                        ...    ...      ...      ...  ...    ...        ...
# 299  대구광역시 달성군 비슬로522길 41 화장사   None        4        0  A02  A0201  A02010800
# 300     대구광역시 북구 호국로51길 45-17   None        4        0  A02  A0201  A02010700
# 301          대구광역시 동구 파계로 741   None        4        0  A02  A0201  A02010700
# 302              대구광역시 중구 동산동   None        4     None  A02  A0203  A02030400
# 303           대구광역시 북구 엑스코로 3   None        4     None  A02  A0202  A02020200
#
# ...

# %%
len(df_daegu)
# Out:
# 304

# %%
# 상세설명 불러오기
daegu_summary = pd.read_csv('대구overview.csv',encoding='utf-8')
daegu_summary
# Out:
#      Unnamed: 0     title                                           overview
# 0             0  가창 찐빵 골목  ※ 영업시간 및 휴무 여부는 가게마다 차이가 있으므로 방문전 전화문의 요망대구에서 ...
# 1             1     감삼못공원  면적 1만 6,332㎡의 작은 공원으로  공원 근처에 달성고등학교, 경운중학교, 두...
# 2             2     강정고령보  경북 고령군 다산면과 대구 달성군 다사읍에 걸쳐 있는 낙동강의 보이자 교랑이다. 4...
# 3             3      경극고택  경주 최씨 집성촌인 옻골마을에 자리잡은 옻골마을은 본래 종가, 장자만 살 수 있었으...
# 4             4    경상감영공원  경상감영공원은 조선 선조 34년(1601) 경상감영이 있던 장소로서 대구도심 중앙에...
# ..          ...       ...                                                ...
# 299          99       화소정  '건강한 아름다움을 담다'는 슬로건을 가진 보자기카페 주식회사 화소정은 대구지역 관...
# 300         100      화암서원  화암서원(華巖書院)은 정조 을유년(乙酉年)에 영남의 많은 사림들이 백인관(白仁寬) ...
# 301         101      화원동산  대구시 달서구와 달성군 사이에 자리한 고장이 화원읍이다.왜관에서 흘러내려온 낙동강이...
# 302         102   화장사(대구)  * 칠성바위라는 지석묘가 있는 사찰, 화장사 *대궁의 외곽지역이었던 달성군 화원읍은...
# 303         103       환성정  1582년에 지어진 환성정은 임진왜란때 대구지방에서 의병장으로 활약한 태암(苔岩) ...
#
# [304 rows x 3 columns]

# %%
addr_daegu = df_daegu['addr1']
title_daegu = df_daegu['title']
mapxxy_daegu = df_daegu.loc[:,'mapx':'mapy']
image_daegu = df_daegu['firstimage']

daeguDf = pd.concat([title_daegu,addr_daegu,mapxxy_daegu,image_daegu], axis=1)
daeguDf

# %%
daegu_tour = pd.merge(daeguDf,daegu_summary)
daegu_tour.drop(["Unnamed: 0"], axis=1, inplace=True)  # Unnamed: 0 열 삭제
daegu_tour
# Out:
#           title                     addr1            mapx           mapy  \
# 0      가창 찐빵 골목    대구광역시 달성군 가창면 가창로 1099  128.6222232980  35.8027142041
# 1         감삼못공원        대구광역시 서구 서대구로3길 43  128.5522334637  35.8586426972
# 2         강정고령보     대구광역시 달성군 다사읍 강정본길 57  128.4650416326  35.8411597415
# 3          경극고택        대구광역시 동구 옻골로 195-3  128.6866758144  35.9074757619
# 4        경상감영공원         대구광역시 중구 경상감영길 99  128.5923073375  35.8720530283
# ..          ...                       ...             ...            ...
# 299     화장사(대구)  대구광역시 달성군 비슬로522길 41 화장사  128.5017700139  35.8027425408
# 300         환성정     대구광역시 북구 호국로51길 45-17  128.5934474273  35.9250303832
# 301   회진당원의대사지비          대구광역시 동구 파계로 741  128.6410022088  36.0013642782
# 302    3.1만세운동길              대구광역시 중구 동산동  128.5866246223  35.8678422889
# 303  FXCO (펙스코)           대구광역시 북구 엑스코로 3  128.6122129743  35.9058967855
#
#                                             firstimage  \
# ...

# %%
daegu_tour.to_csv('대구관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 광주

# %%
gwangju = []
url_gwangju = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=5'
data_xml_gwangju = requests.get(url_gwangju).text
dictionary_gwangju = xmltodict.parse(data_xml_gwangju)
data_json_gwangju = json.loads(json.dumps(dictionary_gwangju) )
data_gwangju = data_json_gwangju['response']['body']['items']['item']
df_gwangju = pd.DataFrame(data_gwangju)

# %%
df_gwangju
# Out:
#                        addr1    addr2 areacode booktour cat1   cat2  \
# 0    광주광역시 광산구 하남대로54번안길 133    (하남동)        5        0  A02  A0202
# 1          광주광역시 광산구 용아로 460    (흑석동)        5        0  A02  A0201
# 2            광주광역시 남구 압촌길 66    (압촌동)        5        0  A02  A0201
# 3           광주광역시 남구 압촌1길 12    (압촌동)        5        0  A02  A0201
# 4            광주광역시 남구 사직길 49     None        5        0  A02  A0201
# ..                       ...      ...      ...      ...  ...    ...
# 151         광주광역시 서구 내방로 152     None        5        0  A02  A0202
# 152        광주광역시 서구 상무평화로 13    (치평동)        5        0  A02  A0202
# 153     광주광역시 남구 천변좌로338번길 7     (구동)        5        0  A02  A0201
# 154        광주광역시 서구 무진대로 919    (광천동)        5        0  A02  A0204
# 155  광주광역시 서구 상무오월로3번길 24-11  1층 윤마블링        5     None  A02  A0203
#
#           cat3 contentid contenttypeid     createdtime  ...  \
# 0    A02020700   2783851            12  20211130232910  ...
# ...

# %%
len(df_gwangju)
# Out:
# 156

# %%
# 상세설명 불러오기
gwangju_summary = pd.read_csv('광주overview.csv',encoding='utf-8')
gwangju_summary
# Out:
#      Unnamed: 0              title  \
# 0             0                경장각
# 1             1              고원희가옥
# 2             2            관덕정의 각궁
# 3             3  광석대 (무등산권 국가지질공원)
# 4             4    광주 3·1 만세운동 기념비
# ..          ...                ...
# 151         151          테라피 스파 소베
# 152         152            현충탑(광주)
# 153         153             황룡친수공원
# 154         154            휴파크 광산점
# 155         155           KBC 광주방송
#
#                                               overview
# 0    경장각은 조선인조(仁祖1551∼1627) 때의 문신(文臣)이었던 이신의(李信儀)을 ...
# 1    임진왜란 때 금산(錦山) 전투에서 전사한 의병장 고경명(高敬命)의 옛 집터를 그 후...
# 2    정신과 신체를 동시에 건강하게 해주는, 관덕정의 각궁 궁술은 무사뿐만이 아니라 선비...
# 3    광석대(규봉 주상절리)는 서석대, 입석대와 함께 무등산을 대표하는 3대 주상절리대로...
# 4    * 수피아 여고생의 넋을 기리는 비, 광주 3·1 만세운동 기념비 *광주는 일제강점...
# ..                                                 ...
# 151  스파 브랜드 ‘테라피 스파 소베’는 라틴어로 건강과 아름다움을 뜻하는 ‘solus’...
# 152  조선시대 때 성거산이라 일컬었던 광주공원은 사직공원과 함께 광주시내에서는 가장 가까...
# ...

# %%
addr_gwangju = df_gwangju['addr1']
title_gwangju = df_gwangju['title']
mapxxy_gwangju = df_gwangju.loc[:,'mapx':'mapy']
image_gwangju = df_gwangju['firstimage']

gwangjuDf = pd.concat([title_gwangju,addr_gwangju,mapxxy_gwangju,image_gwangju], axis=1)
gwangjuDf
# Out:
#                title                    addr1            mapx           mapy  \
# 0             경암근린공원  광주광역시 광산구 하남대로54번안길 133  126.8000950217  35.1783276722
# 1                경장각        광주광역시 광산구 용아로 460  126.8052666353  35.1843631887
# 2              고씨삼강문          광주광역시 남구 압촌길 66  126.8384604525  35.0917964235
# 3              고원희가옥         광주광역시 남구 압촌1길 12  126.8395075721  35.0922075057
# 4            관덕정의 각궁          광주광역시 남구 사직길 49  126.9118638245  35.1419253355
# ..               ...                      ...             ...            ...
# 151        5·18 기념공원         광주광역시 서구 내방로 152  126.8585681905  35.1557506526
# 152        5·18 자유공원        광주광역시 서구 상무평화로 13  126.8399588973  35.1488677834
# 153  (전)광주 성거사지 오층석탑     광주광역시 남구 천변좌로338번길 7  126.9078918037  35.1478718197
# 154         KBC 광주방송        광주광역시 서구 무진대로 919  126.8805327471  35.1624280471
# 155     Yun Marbling  광주광역시 서구 상무오월로3번길 24-11  126.8604235345  35.1576532469
#
# ...

# %%
gwangju_tour = pd.merge(gwangjuDf,gwangju_summary)
gwangju_tour
# Out:
#                title                    addr1            mapx           mapy  \
# 0             경암근린공원  광주광역시 광산구 하남대로54번안길 133  126.8000950217  35.1783276722
# 1                경장각        광주광역시 광산구 용아로 460  126.8052666353  35.1843631887
# 2              고씨삼강문          광주광역시 남구 압촌길 66  126.8384604525  35.0917964235
# 3              고원희가옥         광주광역시 남구 압촌1길 12  126.8395075721  35.0922075057
# 4            관덕정의 각궁          광주광역시 남구 사직길 49  126.9118638245  35.1419253355
# ..               ...                      ...             ...            ...
# 151        5·18 기념공원         광주광역시 서구 내방로 152  126.8585681905  35.1557506526
# 152        5·18 자유공원        광주광역시 서구 상무평화로 13  126.8399588973  35.1488677834
# 153  (전)광주 성거사지 오층석탑     광주광역시 남구 천변좌로338번길 7  126.9078918037  35.1478718197
# 154         KBC 광주방송        광주광역시 서구 무진대로 919  126.8805327471  35.1624280471
# 155     Yun Marbling  광주광역시 서구 상무오월로3번길 24-11  126.8604235345  35.1576532469
#
# ...

# %%
gwangju_tour.to_csv('광주관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 부산

# %%
busan = []
url_busan = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=6'
data_xml_busan = requests.get(url_busan).text
dictionary_busan = xmltodict.parse(data_xml_busan)
data_json_busan = json.loads(json.dumps(dictionary_busan) )
data_busan = data_json_busan['response']['body']['items']['item']
df_busan = pd.DataFrame(data_busan)

# %%
df_busan
# Out:
#                      addr1    addr2 areacode booktour cat1   cat2       cat3  \
# 0      부산광역시 강서구 천성동 308-2     None        6        0  A01  A0101  A01011300
# 1        부산광역시 강서구 외양포로 10     None        6        0  A01  A0101  A01011600
# 2            부산광역시 강서구 천성동     None        6        0  A01  A0101  A01010400
# 3      부산광역시 강서구 대항동 393-9    (대항동)        6        0  A01  A0101  A01011900
# 4      부산광역시 강서구 거가대로 2571    (천성동)        6        0  B01  B0102  B01020500
# ..                     ...      ...      ...      ...  ...    ...        ...
# 297      부산광역시 영도구 절영로 370    (동삼동)        6        0  A02  A0202  A02020700
# 298         부산광역시 중구 남포길 4  (남포동3가)        6        0  A02  A0203  A02030400
# 299  부산광역시 수영구 구락로123번길 20     None        6        0  A02  A0204  A02040800
# 300      부산광역시 부산진구 서면로 39     None        6        0  A02  A0203  A02030400
# 301           부산광역시 남구 대연동     None        6     None  A02  A0202  A02020700
#
# ...

# %%
len(df_busan)
# Out:
# 302

# %%
# 상세설명 불러오기
busan_summary = pd.read_csv('부산overview.csv',encoding='utf-8')
busan_summary
# Out:
#      Unnamed: 0         title  \
# 0             0           가덕도
# 1             1        가덕도 등대
# 2             2     가덕도대항인공동굴
# 3             3     가덕해양파크휴게소
# 4             4          감지해변
# ..          ...           ...
# 297          97      해운대리버크루즈
# 298          98           해월정
# 299          99          혜원정사
# 300         100  KT&G 상상마당 부산
# 301         101        UN조각공원
#
#                                               overview
# 0    가덕도는 부산 최대의 섬으로 자동차로 여행하기 좋은 곳이다. 최고봉인 연대산을 비롯...
# 1    * 고대역사를 간직하고 있는 가덕도 등대 *옛 등대 시설은 사무실과 숙소, 등탑이 ...
# 2    2차 세계대전 말에 일본군은 전력이 급강하하자 부산과 주변 해안에 미군 상륙작전을 ...
# 3    부산~거제 간 연결 도로의 휴게소로 천혜의 자연을 가득 담은 풍경 맛집이다. 부산의...
# 4    부산 태종대 옆에 자리한 감지해변은 길이 270m, 폭 40m의 크기에 부산에서는 ...
# ..                                                 ...
# 297  APEC 나루공원을 출발하여 마린시티, 광안대교를 볼 수 있는 코스로 강과 바다를 ...
# 298  달맞이길 중간에 위치한 해월정은 옛부터 대한팔경의 하나이며 일출의 장관과 월출의 경...
# 299  * 도심에서 만날 수 있는 전통사찰, 혜원정사 *보다 정성 들여 몸과 마음을 순일하...
# ...

# %%
addr_busan = df_busan['addr1']
title_busan = df_busan['title']
mapxxy_busan = df_busan.loc[:,'mapx':'mapy']
image_busan = df_busan['firstimage']

busanDf = pd.concat([title_busan,addr_busan,mapxxy_busan,image_busan], axis=1)
busanDf
# Out:
#             title                  addr1            mapx           mapy  \
# 0             가덕도    부산광역시 강서구 천성동 308-2  128.8169442487  35.0229638330
# 1          가덕도 등대      부산광역시 강서구 외양포로 10  128.8295937487  35.0006471157
# 2         가덕도 연대봉          부산광역시 강서구 천성동  128.8216713782  35.0317518247
# 3       가덕도대항인공동굴    부산광역시 강서구 대항동 393-9  128.8274685924  35.0133095493
# 4       가덕해양파크휴게소    부산광역시 강서구 거가대로 2571  128.8096309940  35.0230581337
# ..            ...                    ...             ...            ...
# 297          75광장      부산광역시 영도구 절영로 370  129.0582219729  35.0706212544
# 298       BIFF 광장         부산광역시 중구 남포길 4  129.0292126150  35.0988508949
# 299         F1963  부산광역시 수영구 구락로123번길 20  129.1155140878  35.1767854293
# 300  KT&G 상상마당 부산      부산광역시 부산진구 서면로 39  129.0573308761  35.1543174256
# 301        UN조각공원           부산광역시 남구 대연동  129.0976280442  35.1297375886
#
#                                             firstimage
# ...

# %%
busan_tour = pd.merge(busanDf,busan_summary)
# 병합하면서 생긴 "Unnamed: 0" 키값 삭제하기
busan_tour.drop(["Unnamed: 0"],axis=1, inplace=True)
busan_tour
# Out:
#             title                  addr1            mapx           mapy  \
# 0             가덕도    부산광역시 강서구 천성동 308-2  128.8169442487  35.0229638330
# 1          가덕도 등대      부산광역시 강서구 외양포로 10  128.8295937487  35.0006471157
# 2         가덕도 연대봉          부산광역시 강서구 천성동  128.8216713782  35.0317518247
# 3       가덕도대항인공동굴    부산광역시 강서구 대항동 393-9  128.8274685924  35.0133095493
# 4       가덕해양파크휴게소    부산광역시 강서구 거가대로 2571  128.8096309940  35.0230581337
# ..            ...                    ...             ...            ...
# 297          75광장      부산광역시 영도구 절영로 370  129.0582219729  35.0706212544
# 298       BIFF 광장         부산광역시 중구 남포길 4  129.0292126150  35.0988508949
# 299         F1963  부산광역시 수영구 구락로123번길 20  129.1155140878  35.1767854293
# 300  KT&G 상상마당 부산      부산광역시 부산진구 서면로 39  129.0573308761  35.1543174256
# 301        UN조각공원           부산광역시 남구 대연동  129.0976280442  35.1297375886
#
#                                             firstimage  \
# ...

# %%
busan_tour.to_csv('부산관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 울산

# %%
ulsan = []
url_ulsan = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=7'
data_xml_ulsan = requests.get(url_ulsan).text
dictionary_ulsan = xmltodict.parse(data_xml_ulsan)
data_json_ulsan = json.loads(json.dumps(dictionary_ulsan) )
data_ulsan = data_json_ulsan['response']['body']['items']['item']
df_ulsan = pd.DataFrame(data_ulsan)
print(len(df_ulsan))
df_ulsan
# Out:
# 168
#                            addr1  addr2 areacode booktour cat1   cat2  \
# 0         울산광역시 울주군 상북면 간월산길 614   None        7        0  A01  A0101
# 1    울산광역시 울주군 상북면 등억알프스로 607-15   None        7        0  A01  A0101
# 2         울산광역시 울주군 상북면 간월산길 614   None        7        0  A01  A0101
# 3       울산광역시 울주군 서생면 간절곶1길 39-2   None        7        0  A01  A0101
# 4              울산광역시 울주군 서생면 나사리   None        7        0  A01  A0101
# ..                           ...    ...      ...      ...  ...    ...
# 163            울산광역시 울주군 상북면 등억리   None        7        0  A01  A0101
# 164           울산광역시 북구 화봉동 324-3   None        7        0  A02  A0202
# 165            울산광역시 동구 화암등대길 50  (방어동)        7        0  A01  A0101
# 166   울산광역시 울주군 웅촌면 통천리 산109-1번지   None        7        0  A01  A0101
# 167             울산광역시 중구 동헌길 167   None        7        0  A02  A0201
#
#           cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
ulsan_summary = pd.read_csv('울산overview.csv',encoding='utf-8')
ulsan_summary
# Out:
#      Unnamed: 0             title  \
# 0             0               간월산
# 1             1         간월산 자연휴양림
# 2             2            간절곶 등대
# 3             3           간절곶 소망길
# 4             4          간절곶소망우체통
# ..          ...               ...
# 163         163  한방테마파크 초락당 (艸樂堂)
# 164         164              한주소금
# 165         165               함월루
# 166         166        현대자동차 울산공장
# 167         167              홍류폭포
#
#                                               overview
# 0    북쪽에 가지산을 두고 서쪽으로 재약산을 바라보며 남쪽에는 신불산과 맞닿아 있는 간월...
# 1    영남의 알프스라 불리는 간월산에 있으며 대자연 곳곳에 마련된 산림욕장, 임간수련장,...
# 2    새로운 천년의 첫해가 한반도에서 가장 먼저 떠오르는 곳, 울주군 서생면 대송리의 간...
# 3    간절곶 소망길은 한반도에서 제일 먼저 새해를 여는 ‘간절곶’의 명칭과 해맞이를 통해...
# 4    울산에서 가볼 만한 곳으로 꼽히는 곳이다. 5m 높이를 자랑하는 소망 우체통은 19...
# ..                                                 ...
# 163  초락당(艸樂堂)은 한방의료를 바탕으로 하여 실시되는 한방헬스투어 전문의료기관으로서 ...
# 164  우리나라 최초의 정제소금 공장으로 해수를 원료로 하는 바다소금이다. 기본에 충실한 ...
# ...

# %%
addr_ulsan = df_ulsan['addr1']
title_ulsan = df_ulsan['title']
mapxxy_ulsan = df_ulsan.loc[:,'mapx':'mapy']
image_ulsan = df_ulsan['firstimage']

ulsanDf = pd.concat([title_ulsan,addr_ulsan,mapxxy_ulsan,image_ulsan], axis=1)
ulsanDf
# Out:
#            title                        addr1            mapx           mapy  \
# 0            간월산       울산광역시 울주군 상북면 간월산길 614  129.0480650268  35.5561610255
# 1      간월산 자연휴양림  울산광역시 울주군 상북면 등억알프스로 607-15  129.0560529115  35.5671043874
# 2            간월재       울산광역시 울주군 상북면 간월산길 614  129.0453821487  35.5482424218
# 3         간절곶 등대     울산광역시 울주군 서생면 간절곶1길 39-2  129.3605738299  35.3589668021
# 4        간절곶 소망길            울산광역시 울주군 서생면 나사리  129.3492110511  35.3546337414
# ..           ...                          ...             ...            ...
# 163         홍류폭포            울산광역시 울주군 상북면 등억리  129.0592308919  35.5498952718
# 164      화동못수변공원           울산광역시 북구 화봉동 324-3  129.3747354806  35.5921547698
# 165       화암추 등대            울산광역시 동구 화암등대길 50  129.4073193497  35.4725716003
# 166     회야댐 생태공원   울산광역시 울주군 웅촌면 통천리 산109-1번지  129.2452780347  35.4683912467
# 167  효자 송도선생 정려비             울산광역시 중구 동헌길 167  129.3203689502  35.5585880748
#
# ...

# %%
ulsan_tour = pd.merge(ulsanDf,ulsan_summary)
ulsan_tour
# Out:
#            title                        addr1            mapx           mapy  \
# 0            간월산       울산광역시 울주군 상북면 간월산길 614  129.0480650268  35.5561610255
# 1      간월산 자연휴양림  울산광역시 울주군 상북면 등억알프스로 607-15  129.0560529115  35.5671043874
# 2            간월재       울산광역시 울주군 상북면 간월산길 614  129.0453821487  35.5482424218
# 3         간절곶 등대     울산광역시 울주군 서생면 간절곶1길 39-2  129.3605738299  35.3589668021
# 4        간절곶 소망길            울산광역시 울주군 서생면 나사리  129.3492110511  35.3546337414
# ..           ...                          ...             ...            ...
# 163         홍류폭포            울산광역시 울주군 상북면 등억리  129.0592308919  35.5498952718
# 164      화동못수변공원           울산광역시 북구 화봉동 324-3  129.3747354806  35.5921547698
# 165       화암추 등대            울산광역시 동구 화암등대길 50  129.4073193497  35.4725716003
# 166     회야댐 생태공원   울산광역시 울주군 웅촌면 통천리 산109-1번지  129.2452780347  35.4683912467
# 167  효자 송도선생 정려비             울산광역시 중구 동헌길 167  129.3203689502  35.5585880748
#
# ...

# %%
ulsan_tour.to_csv('울산관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 세종

# %%
sejong = []
url_sejong = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=8'
data_xml_sejong = requests.get(url_sejong).text
dictionary_sejong = xmltodict.parse(data_xml_sejong)
data_json_sejong = json.loads(json.dumps(dictionary_sejong) )
data_sejong = data_json_sejong['response']['body']['items']['item']
df_sejong = pd.DataFrame(data_sejong)
print(len(df_sejong))
df_sejong
# Out:
# 48
#                        addr1     addr2 areacode booktour cat1   cat2  \
# 0      세종특별자치시 연서면 도신고복로 586      None        8        0  A01  A0101
# 1            세종특별자치시 만남로 151     (고운동)        8        0  A02  A0202
# 2       세종특별자치시 연기면 수목원로 136      None        8        0  A01  A0101
# 3        세종특별자치시 금남면 금천1길 78      None        8        0  A02  A0201
# 4            세종특별자치시 연기면 세종리      None        8        0  A02  A0205
# 5          세종특별자치시 보람동 623-1      None        8        0  A02  A0202
# 6     세종특별자치시 금남면 산림박물관길 110      None        8        0  A01  A0101
# 7      세종특별자치시 금남면 감성길 45-13      None        8        0  A01  A0101
# 8            세종특별자치시 전동면 송성리      None        8        0  A02  A0201
# 9            세종특별자치시 장군면 대교리      None        8        0  A02  A0201
# 10        세종특별자치시 전의면 근성길 14      None        8        0  A02  A0204
# 11     세종특별자치시 연기면 세종리 659-3      None        8        0  A02  A0202
# ...

# %%
# 상세설명 불러오기
sejong_summary = pd.read_csv('세종overview.csv',encoding='utf-8')
sejong_summary
# Out:
#     Unnamed: 0                   title  \
# 0            0                 국립세종수목원
# 1            1                   금강보행교
# 2            2    금강자연휴양림(금강수목원,산림박물관)
# 3            3                도토리숲키즈파크
# 4            4                   뒤웅박고을
# 5            5                  밀마루전망대
# 6            6                방축천 음악분수
# 7            7                  베어트리파크
# 8            8             별신(삼버들협동조합)
# 9            9                 비암사(세종)
# 10          10               뽀로로파크 세종점
# 11          11  세종리 은행나무 (구, 양화리 은행나무)
# 12          12      세종어린이천문대(세종미리내천문대)
# 13          13               세종호수공원 일원
# 14          14              쌍류포도정원협동조합
# 15          15                아람달 체험마을
# 16          16                    연기향교
# 17          17                     영평사
# 18          18                    운주산성
# 19          19                원수산습지생태원
# 20          20                    전의향교
# 21          21                  조천연꽃공원
# 22          22                    합호서원
# ...

# %%
addr_sejong = df_sejong['addr1']
title_sejong = df_sejong['title']
mapxxy_sejong = df_sejong.loc[:,'mapx':'mapy']
image_sejong = df_sejong['firstimage']

sejongDf = pd.concat([title_sejong,addr_sejong,mapxxy_sejong,image_sejong], axis=1)
sejongDf
# Out:
#                      title                     addr1            mapx  \
# 0                   고복자연공원     세종특별자치시 연서면 도신고복로 586  127.2274836912
# 1                    고운뜰공원           세종특별자치시 만남로 151  127.2390461458
# 2                  국립세종수목원      세종특별자치시 연기면 수목원로 136  127.2858062335
# 3                     금강대도       세종특별자치시 금남면 금천1길 78  127.3151939479
# 4                    금강보행교           세종특별자치시 연기면 세종리  127.2888008038
# 5                   금강수변공원         세종특별자치시 보람동 623-1  127.2919894263
# 6     금강자연휴양림(금강수목원,산림박물관)    세종특별자치시 금남면 산림박물관길 110  127.2305767737
# 7                금남 백로 서식지     세종특별자치시 금남면 감성길 45-13  127.2918266309
# 8                      금이성           세종특별자치시 전동면 송성리  127.2039432522
# 9                   김종서장군묘           세종특별자치시 장군면 대교리  127.2158673968
# 10        나무키움(전의양묘영농조합법인)        세종특별자치시 전의면 근성길 14               0
# 11                 달메뜰근린공원     세종특별자치시 연기면 세종리 659-3  127.2750593803
# 12                도토리숲키즈파크       세종특별자치시 장군면 영평사길 34  127.2363001496
# ...

# %%
sejong_tour = pd.merge(sejongDf,sejong_summary)
sejong_tour
# Out:
#                      title                     addr1            mapx  \
# 0                   고복자연공원     세종특별자치시 연서면 도신고복로 586  127.2274836912
# 1                    고운뜰공원           세종특별자치시 만남로 151  127.2390461458
# 2                  국립세종수목원      세종특별자치시 연기면 수목원로 136  127.2858062335
# 3                     금강대도       세종특별자치시 금남면 금천1길 78  127.3151939479
# 4                    금강보행교           세종특별자치시 연기면 세종리  127.2888008038
# 5                   금강수변공원         세종특별자치시 보람동 623-1  127.2919894263
# 6     금강자연휴양림(금강수목원,산림박물관)    세종특별자치시 금남면 산림박물관길 110  127.2305767737
# 7                금남 백로 서식지     세종특별자치시 금남면 감성길 45-13  127.2918266309
# 8                      금이성           세종특별자치시 전동면 송성리  127.2039432522
# 9                   김종서장군묘           세종특별자치시 장군면 대교리  127.2158673968
# 10        나무키움(전의양묘영농조합법인)        세종특별자치시 전의면 근성길 14               0
# 11                 달메뜰근린공원     세종특별자치시 연기면 세종리 659-3  127.2750593803
# 12                도토리숲키즈파크       세종특별자치시 장군면 영평사길 34  127.2363001496
# ...

# %%
sejong_tour.to_csv('세종관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 제주

# %%
jeju = []
url_jeju = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=39'
data_xml_jeju = requests.get(url_jeju).text
dictionary_jeju = xmltodict.parse(data_xml_jeju)
data_json_jeju = json.loads(json.dumps(dictionary_jeju) )
data_jeju = data_json_jeju['response']['body']['items']['item']
df_jeju = pd.DataFrame(data_jeju)
print(len(df_jeju))
df_jeju
# Out:
# 505
#                              addr1     addr2 areacode booktour cat1   cat2  \
# 0            제주특별자치도 제주시 한경면 청수서5길  (한경면) 일원       39        0  A01  A0101
# 1         제주특별자치도 제주시 한경면 청수로 13-3      None       39        0  A01  A0101
# 2           제주특별자치도 서귀포시 표선면 가시리 산  (표선면) 일대       39        0  A01  A0101
# 3                  제주특별자치도 제주시 연미길    (오라삼동)       39        0  A01  A0101
# 4             제주특별자치도 서귀포시 표선면 세화로  (토산리) 일원       39        0  A01  A0101
# ..                             ...       ...      ...      ...  ...    ...
# 500          제주특별자치도 제주시 516로 2927    (아라일동)       39        0  A01  A0101
# 501        제주특별자치도 서귀포시 1100로 1555      None       39        0  A01  A0101
# 502  제주특별자치도 서귀포시 남원읍 신례천로 267-110      None       39        0  A02  A0205
# 503   제주특별자치도 제주시 구좌읍 해맞이해안로 712-3      None       39        0  A02  A0203
# 504            제주특별자치도 제주시 복지로1길 8      None       39        0  A02  A0204
#
#           cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
jeju_summary = pd.read_csv('제주overview.csv',encoding='utf-8')
jeju_summary
# Out:
#      Unnamed: 0          title  \
# 0             0        가메창(암메)
# 1             1            강정천
# 2             2           강정포구
# 3             3        갯깍주상절리대
# 4             4  거문오름 [세계자연유산]
# ..          ...            ...
# 500         500          황우지해안
# 501         501       황우지해안열두굴
# 502         502            후곡악
# 503         503          흙붉은오름
# 504         504         KBS 제주
#
#                                               overview
# 0    저지오름 남서쪽 기슭 자락 도로변에 가마솥 모양으로 패여 있는 원형분화구를 품고 있...
# 1    서귀포시 강정동 마을 동쪽에 있는 강정천은 평소에는 말라버리는 제주도의 일반 하천과...
# 2    해외 휴양지 못지않게 아름다운 자연을 가진 제주도, 그중에서도 서귀포 남쪽 해안을 ...
# 3    갯깍의 ‘갯’은 바다를 뜻하고 ‘깍’은 끄트머리를 의미하는 제주어로 바다 끝머리에 ...
# 4    화구 중심으로부터 유출된 용암류의 침식계곡은 도내 최대 규모로서 전방으로 유선형의 ...
# ..                                                 ...
# 500  황우지해안은 제주도의 대표적인 관광명소 가운데 하나인 외돌개에서 도보로 5분 정도면...
# 501  제주도 내에는 일제 강점기 말에 이르러 일본군이 만든 군사 시설을 심심치 않게 찾아...
# 502  전사면에 부분적으로 삼나무가 조림되어 있고 그외 지역은 풀밭을 이루고 있다. 산 모...
# ...

# %%
addr_jeju = df_jeju['addr1']
title_jeju = df_jeju['title']
mapxxy_jeju = df_jeju.loc[:,'mapx':'mapy']
image_jeju = df_jeju['firstimage']

jejuDf = pd.concat([title_jeju,addr_jeju,mapxxy_jeju,image_jeju], axis=1)
jejuDf
# Out:
#             title                          addr1            mapx  \
# 0            가마오름          제주특별자치도 제주시 한경면 청수서5길  126.2470543070
# 1         가메창(암메)       제주특별자치도 제주시 한경면 청수로 13-3  126.2460707194
# 2    가문이오름(감은이오름)         제주특별자치도 서귀포시 표선면 가시리 산  126.7403699255
# 3           가새기오름                제주특별자치도 제주시 연미길  126.5039945305
# 4            가세오름           제주특별자치도 서귀포시 표선면 세화로  126.7815518045
# ..            ...                            ...             ...
# 500         흙붉은오름          제주특별자치도 제주시 516로 2927  126.5652014016
# 501      1100고지습지        제주특별자치도 서귀포시 1100로 1555  126.4630149420
# 502    5.16 도로숲터널  제주특별자치도 서귀포시 남원읍 신례천로 267-110  126.6304291801
# 503    CFI 에너지미래관   제주특별자치도 제주시 구좌읍 해맞이해안로 712-3               0
# 504        KBS 제주            제주특별자치도 제주시 복지로1길 8  126.5193931884
#
#               mapy                                         firstimage
# 0    33.3056418997                                               None
# ...

# %%
jeju_tour = pd.merge(jejuDf,jeju_summary)
jeju_tour.drop(['Unnamed: 0'],axis=1 , inplace=True)
jeju_tour
# Out:
#             title                          addr1            mapx  \
# 0            가마오름          제주특별자치도 제주시 한경면 청수서5길  126.2470543070
# 1         가메창(암메)       제주특별자치도 제주시 한경면 청수로 13-3  126.2460707194
# 2    가문이오름(감은이오름)         제주특별자치도 서귀포시 표선면 가시리 산  126.7403699255
# 3           가새기오름                제주특별자치도 제주시 연미길  126.5039945305
# 4            가세오름           제주특별자치도 서귀포시 표선면 세화로  126.7815518045
# ..            ...                            ...             ...
# 500         흙붉은오름          제주특별자치도 제주시 516로 2927  126.5652014016
# 501      1100고지습지        제주특별자치도 서귀포시 1100로 1555  126.4630149420
# 502    5.16 도로숲터널  제주특별자치도 서귀포시 남원읍 신례천로 267-110  126.6304291801
# 503    CFI 에너지미래관   제주특별자치도 제주시 구좌읍 해맞이해안로 712-3               0
# 504        KBS 제주            제주특별자치도 제주시 복지로1길 8  126.5193931884
#
#               mapy                                         firstimage  \
# 0    33.3056418997                                               None
# ...

# %%
jeju_tour.to_csv('제주관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 경기도

# %%
gyeonggi = []
url_gyeonggi = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=31'
data_xml_gyeonggi = requests.get(url_gyeonggi).text
dictionary_gyeonggi = xmltodict.parse(data_xml_gyeonggi)
data_json_gyeonggi = json.loads(json.dumps(dictionary_gyeonggi) )
data_gyeonggi = data_json_gyeonggi['response']['body']['items']['item']
df_gyeonggi = pd.DataFrame(data_gyeonggi)
print(len(df_gyeonggi))
df_gyeonggi
# Out:
# 1477
#                             addr1             addr2 areacode booktour cat1  \
# 0             경기도 양주시 장흥면 권율로 117              None       31        0  A01
# 1             경기도 여주시 가남읍 대명산길 98              None       31        0  A02
# 2                       경기 가평군 북면  , 강원특별자치도 춘천시 서면       31        0  A01
# 3             경기도 양평군 지평면 부일길 101             (지평면)       31        0  A02
# 4                 경기도 포천시 이동면 장암리              None       31        0  A01
# ...                           ...               ...      ...      ...  ...
# 1472        경기도 연천군 백학면 노곡로42번길 5              None       31        0  A02
# 1473          경기도 안산시 단원구 순환로 416              (와동)       31        0  A02
# 1474  경기도 파주시 임진각로 148-53 종합관광안내소              None       31     None  A02
# 1475       경기도 가평군 청평면 고재길 262-57              None       31        0  A03
# 1476              경기도 부천시 오정로 233             (오정동)       31        0  A02
#
# ...

# %%
# 상세설명 불러오기
gyeonggi_summary = pd.read_csv('경기도overview.csv',encoding='utf-8')
gyeonggi_summary.drop(["Unnamed: 0"],axis=1,inplace=True)
gyeonggi_summary
# Out:
#             title                                           overview
# 0          가나아트파크  가나아트파크(전, 장흥아트파크)는 1984년 국내 최초 사립미술관인 토탈미술관이 그...
# 1          가남체육공원  가남체육공원은 가남면 태평리에 위치한 주민들을 위한 다목적 체육활동 공원이다. 20...
# 2             가덕산  경기 제1봉인 화악산(1,468m)에서 동남쪽으로 뻗어 내린 능선상에 솟아있는 가덕...
# 3           가루매마을  가루매마을은 칠보산 자락아래 조용하고 편안한 농촌마을로 수도권과 불과 약 30~40...
# 4         가리산(포천)  백운산과 국망봉 사이에 위치한 신로봉에서 서쪽인 이동면 장암리 방면으로 뻗어내린 능...
# ...           ...                                                ...
# 1472         화성어차  순종황제가 타던 자동차와 조선시대 국왕이 탔던 가마를 모티브로 하여 새롭게 탈바꿈한...
# 1473      회암사(양주)  양주시 회암동 천보산(天寶山) 남쪽 기슭에 있는 회암사(檜巖寺)는 1328년(충숙왕...
# 1474          흥왕사  * 소달과 고달 형제의 전설이 있는 사찰, 흥왕사 *흥왕사는 신륵사 하구로 흘러 내...
# 1475     DMZ 생생누리  DMZ 생생누리는 DMZ를 보다 가깝고 생생하게 체험하고 즐길 수 있는 곳이라는 뜻...
# 1476  OBS 방송역사체험관  프로 방송인을 향한 진로 탐색 한국 최초의 방송 미디어 전시관으로, 촬영장 위주의 ...
#
# [1477 rows x 2 columns]

# %%
addr_gyeonggi = df_gyeonggi['addr1']
title_gyeonggi = df_gyeonggi['title']
mapxxy_gyeonggi = df_gyeonggi.loc[:,'mapx':'mapy']
image_gyeonggi = df_gyeonggi['firstimage']

gyeonggiDf = pd.concat([title_gyeonggi,addr_gyeonggi,mapxxy_gyeonggi,image_gyeonggi], axis=1)
gyeonggiDf
# Out:
#                         title                        addr1            mapx  \
# 0                      가나아트파크          경기도 양주시 장흥면 권율로 117  126.9497496852
# 1                      가남체육공원          경기도 여주시 가남읍 대명산길 98  127.5349142281
# 2                         가덕산                    경기 가평군 북면  127.5683098007
# 3                       가루매마을          경기도 양평군 지평면 부일길 101  127.6140193424
# 4                     가리산(포천)              경기도 포천시 이동면 장암리  127.4028046120
# ...                       ...                          ...             ...
# 1472                    38선마을        경기도 연천군 백학면 노곡로42번길 5  126.9236082276
# 1473  4.16희망목공소(4.16희망목공협동조합)          경기도 안산시 단원구 순환로 416  126.8349847878
# 1474                 DMZ 생생누리  경기도 파주시 임진각로 148-53 종합관광안내소  126.7404030300
# 1475                     K-26       경기도 가평군 청평면 고재길 262-57  127.5163098001
# 1476              OBS 방송역사체험관              경기도 부천시 오정로 233  126.7842675560
#
# ...

# %%
# 2개의 데이터프레임의 'title' 값이 같은지 확인 하기 위해서 정렬해주고, 인덱스값 재설정
gyeonggi_summary.sort_values(by='title', ascending=True, inplace=True)
gyeonggi_summary.reset_index(drop=True,inplace=True)
gyeonggiDf.sort_values(by='title', ascending=True ,inplace=True)
gyeonggiDf.reset_index(drop=True, inplace=True)
# 두 데이터프레임의 'title' 값이 서로 같은지 확인 하기 위해서 boolean 이용
len(gyeonggiDf['title'] == gyeonggi_summary['title'])

# %%
# 양쪽의 데이터프레임에 '용화사'라는 value 값이 2개씩 존재해서 삭제
gyeonggiDf = gyeonggiDf.drop(gyeonggiDf[gyeonggiDf['title'] == '용화사'].index)
gyeonggi_summary = gyeonggi_summary.drop(gyeonggi_summary[gyeonggi_summary['title'] == '용화사'].index)

# %%
gyeonggi_summary['title'].value_counts()
# Out:
# 용화사              2
# 1.21 무장공비 침투로    1
# 용주서원             1
# 우둠지              1
# 우농타조농장           1
#                 ..
# 벗고개              1
# 법화산              1
# 법륭사              1
# 법륜사(용인 문수산)      1
# 힐사이드온천텔          1
# Name: title, Length: 1476, dtype: int64

# %%
len(gyeonggiDf['title'] == gyeonggi_summary['title'])
# Out:
# 1477

# %%
gyeonggi_tour = pd.merge(gyeonggiDf,gyeonggi_summary, on='title', how='inner')
gyeonggi_tour.reset_index(drop=True, inplace=True)
gyeonggi_tour
# Out:
#                         title                        addr1            mapx  \
# 0               1.21 무장공비 침투로          경기도 연천군 장남면 반정리 294  126.8281565928
# 1                       38선마을        경기도 연천군 백학면 노곡로42번길 5  126.9236082276
# 2     4.16희망목공소(4.16희망목공협동조합)          경기도 안산시 단원구 순환로 416  126.8349847878
# 3                    DMZ 생생누리  경기도 파주시 임진각로 148-53 종합관광안내소  126.7404030300
# 4                        K-26       경기도 가평군 청평면 고재길 262-57  127.5163098001
# ...                       ...                          ...             ...
# 1470                      흥룡사       경기도 포천시 이동면 포화로 236-73  127.4103058684
# 1471                      흥왕사        경기도 여주시 북내면 당전로 345-4  127.7060862347
# 1472                     희망공원         경기도 시흥시 군자천로131번길 64  126.7150598026
# 1473           힐데루시 자연치유 협동조합  경기도 포천시 신북면 청신로1341번길 10-20  127.1580072674
# 1474                  힐사이드온천텔       경기도 화성시 팔탄면 온천로 428-12  126.8814442063
#
# ...

# %%
gyeonggi_tour['title'].value_counts()
# Out:
# 용화사              4
# 1.21 무장공비 침투로    1
# 용주서원             1
# 우둠지              1
# 우농타조농장           1
#                 ..
# 벗고개              1
# 법화산              1
# 법륭사              1
# 법륜사(용인 문수산)      1
# 힐사이드온천텔          1
# Name: title, Length: 1476, dtype: int64

# %%
gyeonggi_tour.to_csv('경기도관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 강원도

# %%
gangwon = []
url_gangwon = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=32'
data_xml_gangwon = requests.get(url_gangwon).text
dictionary_gangwon = xmltodict.parse(data_xml_gangwon)
data_json_gangwon = json.loads(json.dumps(dictionary_gangwon) )
data_gangwon = data_json_gangwon['response']['body']['items']['item']
df_gangwon = pd.DataFrame(data_gangwon)
print(len(df_gangwon))
df_gangwon
# Out:
# 1371
#                             addr1                addr2 areacode booktour cat1  \
# 0             강원특별자치도 삼척시 가곡면 탕곡리                509-3       32     None  A02
# 1             강원특별자치도 홍천군 내촌면 와야리                 None       32        0  A01
# 2      강원특별자치도 홍천군 두촌면 가리산길 260-9                (두촌면)       32        0  A01
# 3        강원특별자치도 홍천군 두촌면 가리산길 426                (두촌면)       32        0  A01
# 4       강원특별자치도 정선군 정선읍 가리왕산로 707  (가리왕산자연휴양림), 평창 진부면       32        0  A01
# ...                           ...                  ...      ...      ...  ...
# 1366         강원특별자치도 양구군 해안서화로 23                 None       32        0  A02
# 1367     강원특별자치도 평창군 미탄면 마하길 41-5                 None       32        0  A02
# 1368  강원특별자치도 고성군 죽왕면 심층수길 124-19                (죽왕면)       32        0  A02
# 1369       강원특별자치도 홍천군 내면 원자운길 38                 None       32        0  A02
# 1370      강원특별자치도 평창군 문화택지길 41-12                 None       32     None  A02
#
# ...

# %%
# 상세설명 불러오기
gangwon_summary = pd.read_csv('강원도overview.csv',encoding='utf-8')
gangwon_summary
# Out:
#       Unnamed: 0        title  \
# 0              0    가곡유황온천&스파
# 1              1         가령폭포
# 2              2      가리산(홍천)
# 3              3     가리산자연휴양림
# 4              4         가리왕산
# ...          ...          ...
# 1366         166       38평화마을
# 1367         167         38해변
# 1368         168     (구)태백등기소
# 1369         169   DMZ산림두드림센터
# 1370         170  故박정렬여사 추모공원
#
#                                                overview
# 0     가곡 유황온천&스파는 자연에서 솟아나는 유황온천을 즐길 수 있는 곳이다. 가곡면의 ...
# 1     가령폭포는 자연속에 숨겨진 오지의 백암산(1,099m) 서남쪽 기슭에 숨어 있으며 ...
# 2     해발 1,050.9m의 고산으로 춘천시와 홍천군의 경계지역에 위치하며, 산 정상에 ...
# 3     두촌면 천현리 가리산(해발 1,051m) 기슭의 우거진 숲과 노송들이 기암괴석과  ...
# 4     정선읍 회동리, 북평면 숙암리에 위치하면 우리나라의 명산으로 널리 알려진 가리왕산은...
# ...                                                 ...
# 1366  38평화마을은 한국전쟁의 아픔과 추억을 고스란히 간직한 양양군 잔교리의 작은 마을로...
# 1367  38해변은 38(휴게소) 부근에 위치한 해변으로 7번국도변에 있어 접근이 양호하며 ...
# 1368  태백시에 현존하고 있는 가장 오래된 관공서로 지역 특유의 역사적, 건축사적 가치를 ...
# ...

# %%
addr_gangwon = df_gangwon['addr1']
title_gangwon = df_gangwon['title']
mapxxy_gangwon = df_gangwon.loc[:,'mapx':'mapy']
image_gangwon = df_gangwon['firstimage']

gangwonDf = pd.concat([title_gangwon,addr_gangwon,mapxxy_gangwon,image_gangwon], axis=1)
gangwonDf
# Out:
#             title                        addr1            mapx           mapy  \
# 0       가곡유황온천&스파          강원특별자치도 삼척시 가곡면 탕곡리  129.2062296318  37.1507494904
# 1            가령폭포          강원특별자치도 홍천군 내촌면 와야리  128.1601919204  37.8328951114
# 2         가리산(홍천)   강원특별자치도 홍천군 두촌면 가리산길 260-9  127.9566453426  37.8716589858
# 3        가리산자연휴양림     강원특별자치도 홍천군 두촌면 가리산길 426  127.9795073354  37.8656156746
# 4            가리왕산    강원특별자치도 정선군 정선읍 가리왕산로 707  128.5634777835  37.4618262980
# ...           ...                          ...             ...            ...
# 1366    DMZ펀치볼둘레길         강원특별자치도 양구군 해안서화로 23  128.1442044239  38.2906137518
# 1367       WOW:미탄     강원특별자치도 평창군 미탄면 마하길 41-5  128.5410987766  37.2917010437
# 1368       ㈜강원심층수  강원특별자치도 고성군 죽왕면 심층수길 124-19  128.5216381039  38.3343742648
# 1369  故박정렬여사 추모공원       강원특별자치도 홍천군 내면 원자운길 38  128.3606601431  37.7321800501
# 1370  食 休 耕 (식휴경)      강원특별자치도 평창군 문화택지길 41-12  128.4535784664  37.4909569494
#
# ...

# %%
gangwon_summary['title'].value_counts()
gangwon_summary = gangwon_summary.drop(gangwon_summary[gangwon_summary['title'] == '후진항'].index)
gangwon_summary = gangwon_summary.drop(gangwon_summary[gangwon_summary['title'] == '복분리해수욕장'].index)
gangwon_summary = gangwon_summary.drop(gangwon_summary[gangwon_summary['title'] == '두타산'].index)

# %%
gangwonDf['title'].value_counts()
gangwonDf = gangwonDf.drop(gangwonDf[gangwonDf['title'] == '후진항'].index)
gangwonDf = gangwonDf.drop(gangwonDf[gangwonDf['title'] == '복분리해수욕장'].index)
gangwonDf = gangwonDf.drop(gangwonDf[gangwonDf['title'] == '두타산'].index)

# %%
gangwon_tour = pd.merge(gangwonDf,gangwon_summary, on='title', how='inner')
gangwon_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
gangwon_tour
# Out:
#             title                        addr1            mapx           mapy  \
# 0       가곡유황온천&스파          강원특별자치도 삼척시 가곡면 탕곡리  129.2062296318  37.1507494904
# 1            가령폭포          강원특별자치도 홍천군 내촌면 와야리  128.1601919204  37.8328951114
# 2         가리산(홍천)   강원특별자치도 홍천군 두촌면 가리산길 260-9  127.9566453426  37.8716589858
# 3        가리산자연휴양림     강원특별자치도 홍천군 두촌면 가리산길 426  127.9795073354  37.8656156746
# 4            가리왕산    강원특별자치도 정선군 정선읍 가리왕산로 707  128.5634777835  37.4618262980
# ...           ...                          ...             ...            ...
# 1364    DMZ펀치볼둘레길         강원특별자치도 양구군 해안서화로 23  128.1442044239  38.2906137518
# 1365       WOW:미탄     강원특별자치도 평창군 미탄면 마하길 41-5  128.5410987766  37.2917010437
# 1366       ㈜강원심층수  강원특별자치도 고성군 죽왕면 심층수길 124-19  128.5216381039  38.3343742648
# 1367  故박정렬여사 추모공원       강원특별자치도 홍천군 내면 원자운길 38  128.3606601431  37.7321800501
# 1368  食 休 耕 (식휴경)      강원특별자치도 평창군 문화택지길 41-12  128.4535784664  37.4909569494
#
# ...

# %%
gangwon_tour.to_csv('강원관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 충북

# %%
chungbuk = []
url_chungbuk = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=33'
data_xml_chungbuk = requests.get(url_chungbuk).text
dictionary_chungbuk = xmltodict.parse(data_xml_chungbuk)
data_json_chungbuk = json.loads(json.dumps(dictionary_chungbuk) )
data_chungbuk = data_json_chungbuk['response']['body']['items']['item']
df_chungbuk = pd.DataFrame(data_chungbuk)
print(len(df_chungbuk))
df_chungbuk
# Out:
# 734
#                          addr1         addr2 areacode booktour cat1   cat2  \
# 0       충청북도 옥천군 안내면 안내회남로 671          None       33        0  A02  A0201
# 1         충청북도 음성군 음성읍 가섭길 494          None       33        0  A02  A0201
# 2         충청북도 괴산군 칠성면 각연길 451          None       33        0  A02  A0201
# 3             충청북도 영동군 양산면 호탄리          None       33        0  A01  A0101
# 4        충청북도 괴산군 칠성면 사은리 92-1          None       33        0  A01  A0101
# ..                         ...           ...      ...      ...  ...    ...
# 729    충청북도 보은군 회인면 부수1길 31-11          None       33        0  A02  A0201
# 730  충청북도 괴산군 청천면 후평도원로 129-19          None       33        0  A02  A0202
# 731               충청북도 괴산군 연풍면  경상북도 문경시 가은읍       33        0  A01  A0101
# 732      충청북도 진천군 진천읍 씨제이로 110          None       33        0  A02  A0204
# 733       충청북도 충주시 수안보면 물탕2길 9          None       33        0  A02  A0202
#
#           cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
chungbuk_summary = pd.read_csv('충청북도overview.csv',encoding='utf-8')
chungbuk_summary
# Out:
#      Unnamed: 0        title  \
# 0             0          가섭사
# 1             1      각연사(괴산)
# 2             2          갈기산
# 3             3         갈론계곡
# 4             4  감곡매괴성모순례지성당
# ..          ...          ...
# 729         129     화양서원 묘정비
# 730         130       화인산림욕장
# 731         131  황강 영당 및 수암사
# 732         132         회인향교
# 733         133       후평숲유원지
#
#                                               overview
# 0    석가모니의 10대 제자 중 수석제자로‘가섭존자(迦葉尊者)’가 있다 그는 석가 열반 ...
# 1    신라 법흥왕때에 유일대사가 현재의 충북 괴산군 칠성면 쌍곡리근처에 터를 잡고 절을 ...
# 2    해발 585m의 갈기산은 이름 그대로 말갈기와 흡사하다 하여 이름 지여졌는데 바위가...
# 3    계곡 인근에 갈씨 성을 가진 사람들이 많이 살았다고 해서 이름 붙여진 갈론계곡은 아...
# 4    감곡본당은 1896년 설립되어 100년이 넘는 역사를 간직하고 있는 곳이다. 초대 ...
# ..                                                 ...
# 729  화양계곡 내에 있는 화양서원 묘정비이다. 묘정비는 서원 앞에 세워 서원의 건립취지와...
# 730  끝없이 솟은 메타세쿼이아가 맞아주는 곳, 화인산림욕장은 40여 년 전 이곳 부지를 ...
# 731  조선 주자학의 대가인 송시열과 그의 제자인 권상하와 권상하의 제자  한원진, 윤봉구...
# ...

# %%
addr_chungbuk = df_chungbuk['addr1']
title_chungbuk = df_chungbuk['title']
mapxxy_chungbuk = df_chungbuk.loc[:,'mapx':'mapy']
image_chungbuk = df_chungbuk['firstimage']

chungbukDf = pd.concat([title_chungbuk,addr_chungbuk,mapxxy_chungbuk,image_chungbuk], axis=1)
chungbukDf
# Out:
#                    title                      addr1            mapx  \
# 0                    가산사     충청북도 옥천군 안내면 안내회남로 671  127.5973920906
# 1                    가섭사       충청북도 음성군 음성읍 가섭길 494  127.7030557496
# 2                각연사(괴산)       충청북도 괴산군 칠성면 각연길 451  127.9274860663
# 3                    갈기산           충청북도 영동군 양산면 호탄리  127.6280083624
# 4                   갈론계곡      충청북도 괴산군 칠성면 사은리 92-1  127.8569707814
# ..                   ...                        ...             ...
# 729                 회인향교    충청북도 보은군 회인면 부수1길 31-11  127.6014974276
# 730               후평숲유원지  충청북도 괴산군 청천면 후평도원로 129-19  127.7561263168
# 731                  희양산               충청북도 괴산군 연풍면  128.0046552552
# 732  CJ 블로썸 캠퍼스 (CJ제일제당)      충청북도 진천군 진천읍 씨제이로 110  127.4607939186
# 733         RI온천(RI온천호텔)       충청북도 충주시 수안보면 물탕2길 9  127.9901111697
#
#               mapy                                         firstimage
# 0    36.4015885618                                               None
# ...

# %%
chungbukDf['title'].value_counts()
chungbukDf = chungbukDf.drop(chungbukDf[chungbukDf['title'] == '솔밭공원'].index)
chungbukDf
# Out:
#                    title                      addr1            mapx  \
# 0                    가산사     충청북도 옥천군 안내면 안내회남로 671  127.5973920906
# 1                    가섭사       충청북도 음성군 음성읍 가섭길 494  127.7030557496
# 2                각연사(괴산)       충청북도 괴산군 칠성면 각연길 451  127.9274860663
# 3                    갈기산           충청북도 영동군 양산면 호탄리  127.6280083624
# 4                   갈론계곡      충청북도 괴산군 칠성면 사은리 92-1  127.8569707814
# ..                   ...                        ...             ...
# 729                 회인향교    충청북도 보은군 회인면 부수1길 31-11  127.6014974276
# 730               후평숲유원지  충청북도 괴산군 청천면 후평도원로 129-19  127.7561263168
# 731                  희양산               충청북도 괴산군 연풍면  128.0046552552
# 732  CJ 블로썸 캠퍼스 (CJ제일제당)      충청북도 진천군 진천읍 씨제이로 110  127.4607939186
# 733         RI온천(RI온천호텔)       충청북도 충주시 수안보면 물탕2길 9  127.9901111697
#
#               mapy                                         firstimage
# 0    36.4015885618                                               None
# ...

# %%
chungbuk_summary['title'].value_counts()
chungbuk_summary = chungbuk_summary.drop(chungbuk_summary[chungbuk_summary['title'] == '솔밭공원'].index)

# %%
chungbuk_tour = pd.merge(chungbukDf,chungbuk_summary, on='title', how='inner')
chungbuk_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
chungbuk_tour
# Out:
#                    title                      addr1            mapx  \
# 0                    가산사     충청북도 옥천군 안내면 안내회남로 671  127.5973920906
# 1                    가섭사       충청북도 음성군 음성읍 가섭길 494  127.7030557496
# 2                각연사(괴산)       충청북도 괴산군 칠성면 각연길 451  127.9274860663
# 3                    갈기산           충청북도 영동군 양산면 호탄리  127.6280083624
# 4                   갈론계곡      충청북도 괴산군 칠성면 사은리 92-1  127.8569707814
# ..                   ...                        ...             ...
# 727                 회인향교    충청북도 보은군 회인면 부수1길 31-11  127.6014974276
# 728               후평숲유원지  충청북도 괴산군 청천면 후평도원로 129-19  127.7561263168
# 729                  희양산               충청북도 괴산군 연풍면  128.0046552552
# 730  CJ 블로썸 캠퍼스 (CJ제일제당)      충청북도 진천군 진천읍 씨제이로 110  127.4607939186
# 731         RI온천(RI온천호텔)       충청북도 충주시 수안보면 물탕2길 9  127.9901111697
#
#               mapy                                         firstimage  \
# 0    36.4015885618                                               None
# ...

# %%
chungbuk_tour.to_csv('충북관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 충남

# %%
chungnam = []
url_chungnam = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=34'
data_xml_chungnam = requests.get(url_chungnam).text
dictionary_chungnam = xmltodict.parse(data_xml_chungnam)
data_json_chungnam = json.loads(json.dumps(dictionary_chungnam) )
data_chungnam = data_json_chungnam['response']['body']['items']['item']
df_chungnam = pd.DataFrame(data_chungnam)
print(len(df_chungnam))
df_chungnam
# Out:
# 858
#                           addr1  addr2 areacode booktour  cat1   cat2  \
# 0              충청남도 서산시 해미면 산수리   None       34        0   A01  A0101
# 1             충청남도 태안군 근흥면 가의도길   None       34        0   A01  A0101
# 2        충청남도 청양군 대치면 가파로 506-6   None       34        0   A02  A0203
# 3         충청남도 천안시 동남구 각원사길 245  (안서동)       34        0   A02  A0201
# 4    충청남도 부여군 임천면 성흥로283번길 31-4   None       34        0   A02  A0201
# ..                          ...    ...      ...      ...   ...    ...
# 853  충청남도 논산시 강경읍 옥녀봉로27번길 30-5  (강경읍)       34        0   A02  A0201
# 854    충청남도 논산시 강경읍 계백로167번길 50   None       34        0   A02  A0201
# 855             충청남도 금산군 비단로 36   None       34     None  None   None
# 856      충청남도 금산군 비단로 111 백호세탁소  1층 1호       34     None  None   None
# 857            충청남도 보령시 대해로 876  (신흑동)       34        0   A02  A0202
#
#           cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
chungnam_summary = pd.read_csv('충청남도overview.csv',encoding='utf-8')
chungnam_summary
# Out:
#      Unnamed: 0         title  \
# 0             0       가야산(서산)
# 1             1          가파마을
# 2             2           각원사
# 3             3  간월도 어리굴젓 기념탑
# 4             4         간월도마을
# ..          ...           ...
# 853          53           황포항
# 854          54           효자도
# 855          55       히흣 도예공방
# 856          56     (구)강경노동조합
# 857          57  (구)한일은행 강경지점
#
#                                               overview
# 0    주봉인 가야봉(677.6m)을 중심으로 원효봉(677m), 옥양봉(621.4m), ...
# 1    아름다운 언덕마을인 가파마을에는 '세 가지 아름다움(3嘉)’이 있는데 이 곳에 다녀...
# 2    태조산은 천안의 진산으로 유량천, 산방천의 분수령을 이루고 있고 정상에 오르면 천안...
# 3    간월도에 들어서면 어리굴젓 기념탑이 먼저 눈길을 끈다. 그만큼 굴이 유명하다는 얘기...
# 4    서산A지구 방조제 중앙에 위치하여 남쪽으로는 약 30km 길게 펼쳐진 천수만이 있고...
# ..                                                 ...
# 853  황포항은 충남 태안군 안면읍에 자리 잡고 있다. 2004년 어촌정주어항으로 지정됐다...
# 854  대천항에서 8.7km 떨어진 곳에 위치한 면적 1.34㎢, 해안선 길이 5.4㎞의 ...
# 855  히흣 도예공방은 미래의 주인공인 어린이와 학부모님 그리고 일반인이 다함께 만들기 체...
# ...

# %%
addr_chungnam = df_chungnam['addr1']
title_chungnam = df_chungnam['title']
mapxxy_chungnam = df_chungnam.loc[:,'mapx':'mapy']
image_chungnam = df_chungnam['firstimage']

chungnamDf = pd.concat([title_chungnam,addr_chungnam,mapxxy_chungnam,image_chungnam], axis=1)
chungnamDf
# Out:
#             title                       addr1            mapx           mapy  \
# 0         가야산(서산)            충청남도 서산시 해미면 산수리  126.6091060355  36.7039864327
# 1             가의도           충청남도 태안군 근흥면 가의도길  126.0749440746  36.6730836379
# 2            가파마을      충청남도 청양군 대치면 가파로 506-6  126.8796427201  36.4976315311
# 3             각원사       충청남도 천안시 동남구 각원사길 245  127.1970050154  36.8340789963
# 4            간곡서원  충청남도 부여군 임천면 성흥로283번길 31-4  126.9083485111  36.1824820312
# ..            ...                         ...             ...            ...
# 853     (구)강경노동조합  충청남도 논산시 강경읍 옥녀봉로27번길 30-5  127.0145979053  36.1608696794
# 854  (구)한일은행 강경지점    충청남도 논산시 강경읍 계백로167번길 50  127.0152089296  36.1620834404
# 855      (주)다다컴퍼니             충청남도 금산군 비단로 36  127.4844464970  36.0991099782
# 856  (주)손으로만드는수공예      충청남도 금산군 비단로 111 백호세탁소  127.4928735241  36.0991295697
# 857   JFK 대천 워터파크            충청남도 보령시 대해로 876  126.5175803044  36.3074221101
#
# ...

# %%
chungnamDf['title'].value_counts()
# Out:
# 가야산(서산)           1
# 예당호 출렁다리(음악분수)    1
# 예산 알토란사과마을        1
# 예산 용궁리 백송         1
# 예산 임존성            1
#                  ..
# 문수사(서산)           1
# 문헌서원              1
# 미나릿길벽화마을          1
# 미르섬               1
# JFK 대천 워터파크       1
# Name: title, Length: 858, dtype: int64

# %%
chungnam_summary['title'].value_counts()
# Out:
# 가야산(서산)          1
# 홍성 홍주의사총         1
# 홍성호              1
# 홍예공원             1
# 홍원항              1
#                 ..
# 소노벨 천안 오션어드벤처    1
# 소도               1
# 소찬 협동조합          1
# 속동전망대            1
# (구)한일은행 강경지점     1
# Name: title, Length: 858, dtype: int64

# %%
chungnam_tour = pd.merge(chungnamDf,chungnam_summary, on='title', how='inner')
chungnam_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
chungnam_tour
# Out:
#             title                       addr1            mapx           mapy  \
# 0         가야산(서산)            충청남도 서산시 해미면 산수리  126.6091060355  36.7039864327
# 1             가의도           충청남도 태안군 근흥면 가의도길  126.0749440746  36.6730836379
# 2            가파마을      충청남도 청양군 대치면 가파로 506-6  126.8796427201  36.4976315311
# 3             각원사       충청남도 천안시 동남구 각원사길 245  127.1970050154  36.8340789963
# 4            간곡서원  충청남도 부여군 임천면 성흥로283번길 31-4  126.9083485111  36.1824820312
# ..            ...                         ...             ...            ...
# 853     (구)강경노동조합  충청남도 논산시 강경읍 옥녀봉로27번길 30-5  127.0145979053  36.1608696794
# 854  (구)한일은행 강경지점    충청남도 논산시 강경읍 계백로167번길 50  127.0152089296  36.1620834404
# 855      (주)다다컴퍼니             충청남도 금산군 비단로 36  127.4844464970  36.0991099782
# 856  (주)손으로만드는수공예      충청남도 금산군 비단로 111 백호세탁소  127.4928735241  36.0991295697
# 857   JFK 대천 워터파크            충청남도 보령시 대해로 876  126.5175803044  36.3074221101
#
# ...

# %%
chungnam_tour.to_csv('충남관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 경북

# %%
gyeongbuk = []
url_gyeongbuk = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=35'
data_xml_gyeongbuk = requests.get(url_gyeongbuk).text
dictionary_gyeongbuk = xmltodict.parse(data_xml_gyeongbuk)
data_json_gyeongbuk = json.loads(json.dumps(dictionary_gyeongbuk) )
data_gyeongbuk = data_json_gyeongbuk['response']['body']['items']['item']
df_gyeongbuk = pd.DataFrame(data_gyeongbuk)
print(len(df_gyeongbuk))
df_gyeongbuk
# Out:
# 1276
#                                      addr1 addr2 areacode booktour cat1  \
# 0                    경상북도 영천시 화산면 가래실로 364  None       35        0  A02
# 1                     경상북도 칠곡군 가산면 가산로 891  None       35        0  A02
# 2                  경상북도 칠곡군 가산면 학하들안2길 105  None       35        0  A01
# 3                      경상북도 칠곡군 왜관읍 가실1길 1  None       35        0  A02
# 4                  경상북도 성주군 수륜면 가야산식물원길 49  None       35        0  A01
# ...                                    ...   ...      ...      ...  ...
# 1271                 경상북도 포항시 북구 화두길 32-45  None       35        0  A02
# 1272                      경상북도 봉화군 명호면 풍호리  None       35        0  A02
# 1273                경상북도 의성군 사곡면 의성사곡로 993  None       35        0  A02
# 1274  경상북도 경주시 천북남로 196 MCY PARK(햇살가득한 캠핑)  None       35     None  A02
# 1275             경상북도 포항시 남구 동해안로6213번길 14  None       35        0  A02
#
#        cat2       cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
gyeongbuk_summary = pd.read_csv('경상북도overview.csv',encoding='utf-8')
gyeongbuk_summary
# Out:
#       Unnamed: 0                  title  \
# 0              0                 가산산성마을
# 1              1                  가산수피아
# 2              2                   가실성당
# 3              3             가야산 야생화식물원
# 4              4             가야산역사신화테마관
# ...          ...                    ...
# 1271          71                   후산정사
# 1272          72               후포리 벽화마을
# 1273          73                   훈령서원
# 1274          74                   희방폭포
# 1275          75  (구)사곡중학교 메밀꽃밭(허수아비공원)
#
#                                                overview
# 0     맑은물, 깨끗한 자연, 좋은 사람들이 함께하는 구름도 쉬어가는 아름다운 청정마을 가...
# 1     싱그러운 자연숲과 향기로운 허브정원, 아름답게 펼쳐진 핑크뮬리 언덕, 문화 예술이 ...
# 2     가실성당은 1895년에 조선 교구의 11번째 본당으로 초대본당신부는 파리외방선교회의...
# 3     2006년 6월 16일 개관한 국내 최초 야생화 전문식물원이다. 총 400여종의 수...
# 4     가야문화권의 역사와 신화, 가야산의 생태를 테마로한 2층 규모의 전시 테마관이며, ...
# ...                                                 ...
# 1271  김사원이 세상을 떠나자 그의 덕망을 추모하여 후손들이 안동 도산에 천산정사를 세웠으...
# ...

# %%
addr_gyeongbuk = df_gyeongbuk['addr1']
title_gyeongbuk = df_gyeongbuk['title']
mapxxy_gyeongbuk = df_gyeongbuk.loc[:,'mapx':'mapy']
image_gyeongbuk = df_gyeongbuk['firstimage']

gyeongbukDf = pd.concat([title_gyeongbuk,addr_gyeongbuk,mapxxy_gyeongbuk,image_gyeongbuk], axis=1)
gyeongbukDf
# Out:
#                                 title                                 addr1  \
# 0                            가래실 문화마을                 경상북도 영천시 화산면 가래실로 364
# 1                              가산산성마을                  경상북도 칠곡군 가산면 가산로 891
# 2                               가산수피아               경상북도 칠곡군 가산면 학하들안2길 105
# 3                                가실성당                   경상북도 칠곡군 왜관읍 가실1길 1
# 4                          가야산 야생화식물원               경상북도 성주군 수륜면 가야산식물원길 49
# ...                               ...                                   ...
# 1271  힐링로드(청하체리힐, 드로잉체리공방/누나서프/HJ디저트)                 경상북도 포항시 북구 화두길 32-45
# 1272                       35번 국도 선유교                      경상북도 봉화군 명호면 풍호리
# 1273            (구)사곡중학교 메밀꽃밭(허수아비공원)                경상북도 의성군 사곡면 의성사곡로 993
# 1274                         MCY PARK  경상북도 경주시 천북남로 196 MCY PARK(햇살가득한 캠핑)
# 1275                PARK 1538 포스코 역사관             경상북도 포항시 남구 동해안로6213번길 14
#
#                 mapx           mapy  \
# ...

# %%
gyeongbukDf = gyeongbukDf.drop(gyeongbukDf[gyeongbukDf['title'] == '금호서원'].index)
gyeongbukDf = gyeongbukDf.drop(gyeongbukDf[gyeongbukDf['title'] == '도계서원'].index)
gyeongbukDf = gyeongbukDf.drop(gyeongbukDf[gyeongbukDf['title'] == '간절곶'].index)

gyeongbukDf['title'].value_counts()
# Out:
# 가래실 문화마을             1
# 옥산 세심마을              1
# 완귀정                  1
# 와우 주                 1
# 와룡암                  1
#                     ..
# 문경새재 반려동물 힐링센터       1
# 문경새재 3관문(조령관)        1
# 문경단산 모노레일            1
# 문경 오미자테마공원           1
# PARK 1538 포스코 역사관    1
# Name: title, Length: 1271, dtype: int64

# %%
gyeongbuk_summary = gyeongbuk_summary.drop(gyeongbuk_summary[gyeongbuk_summary['title'] == '금호서원'].index)
gyeongbuk_summary = gyeongbuk_summary.drop(gyeongbuk_summary[gyeongbuk_summary['title'] == '도계서원'].index)
gyeongbuk_summary = gyeongbuk_summary.drop(gyeongbuk_summary[gyeongbuk_summary['title'] == '간절곶'].index)

gyeongbuk_summary['title'].value_counts()
# Out:
# 가산산성마을                   1
# 경주 서악동 고분군               1
# 경주 진덕여왕릉                 1
# 경주 재매정                   1
# 경주 일성왕릉                  1
#                         ..
# 신돌석장군 생가 및 유적지           1
# 승부역(봉화)                  1
# 승곡마을                     1
# 숫돌바위 (울릉도, 독도 국가지질공원)    1
# (구)사곡중학교 메밀꽃밭(허수아비공원)    1
# Name: title, Length: 1271, dtype: int64

# %%
gyeongbuk_tour = pd.merge(gyeongbukDf,gyeongbuk_summary, on='title', how='inner')
gyeongbuk_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
gyeongbuk_tour
# Out:
#                                 title                                 addr1  \
# 0                            가래실 문화마을                 경상북도 영천시 화산면 가래실로 364
# 1                              가산산성마을                  경상북도 칠곡군 가산면 가산로 891
# 2                               가산수피아               경상북도 칠곡군 가산면 학하들안2길 105
# 3                                가실성당                   경상북도 칠곡군 왜관읍 가실1길 1
# 4                          가야산 야생화식물원               경상북도 성주군 수륜면 가야산식물원길 49
# ...                               ...                                   ...
# 1266  힐링로드(청하체리힐, 드로잉체리공방/누나서프/HJ디저트)                 경상북도 포항시 북구 화두길 32-45
# 1267                       35번 국도 선유교                      경상북도 봉화군 명호면 풍호리
# 1268            (구)사곡중학교 메밀꽃밭(허수아비공원)                경상북도 의성군 사곡면 의성사곡로 993
# 1269                         MCY PARK  경상북도 경주시 천북남로 196 MCY PARK(햇살가득한 캠핑)
# 1270                PARK 1538 포스코 역사관             경상북도 포항시 남구 동해안로6213번길 14
#
#                 mapx           mapy  \
# ...

# %%
gyeongbuk_tour.to_csv('경북관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 경남

# %%
gyeongnam = []
url_gyeongnam = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=36'
data_xml_gyeongnam = requests.get(url_gyeongnam).text
dictionary_gyeongnam = xmltodict.parse(data_xml_gyeongnam)
data_json_gyeongnam = json.loads(json.dumps(dictionary_gyeongnam) )
data_gyeongnam = data_json_gyeongnam['response']['body']['items']['item']
df_gyeongnam = pd.DataFrame(data_gyeongnam)
print(len(df_gyeongnam))
df_gyeongnam
# Out:
# 1345
#                           addr1   addr2 areacode booktour cat1   cat2  \
# 0     경상남도 창원시 마산합포구 성호서7길 15-8    None       36        0  A02  A0203
# 1              경상남도 거제시 남부면 다대리   (남부면)       36        0  A01  A0101
# 2          경상남도 진주시 명석면 관덕길 174   (명석면)       36        0  A02  A0203
# 3              경상남도 거제시 동부면 가배리    None       36        0  A02  A0201
# 4           경상남도 양산시 동면 가산리 799    None       36        0  A02  A0202
# ...                         ...     ...      ...      ...  ...    ...
# 1340        경상남도 김해시 전하로 269-74    (외동)       36        0  A02  A0201
# 1341       경상남도 창원시 진해구 남영로 280   (남문동)       36        0  A02  A0202
# 1342     경상남도 통영시 욕지면 욕지일주로 352    None       36        0  A01  A0101
# 1343       경상남도 창원시 마산합포구 월남동1가    47-4       36     None  A02  A0202
# 1344            경상남도 진주시 충의로 19  (충무공동)       36        0  A02  A0204
#
#            cat3 contentid contenttypeid     createdtime  ...  \
# ...

# %%
# 상세설명 불러오기
gyeongnam_summary = pd.read_csv('경상남도overview.csv',encoding='utf-8')
gyeongnam_summary
# Out:
#       Unnamed: 0          title  \
# 0              0  가고파 꼬부랑길 벽화마을
# 1              1            가라산
# 2              2          가뫼골마을
# 3              3         가산수변공원
# 4              4  가섭암지 마애여래삼존입상
# ...          ...            ...
# 1340         140           효산서원
# 1341         141         흥남해수욕장
# 1342         142          흰돌메공원
# 1343         143          흰작살해변
# 1344         144     LH 토지주택박물관
#
#                                                overview
# 0     가고파 꼬부랑길벽화마을은 2013년 12월 추산동과 성호동 일대 30여 가구를 잇는...
# 1     거제의 최남단 해변에 위치한 가라산은 거제에서 제일 높은 산으로 그 높이는 585m...
# 2     넉넉하고 훈훈한 시골인심을 그대로 간직한 가뫼골 녹색농촌체험마을이다. 농촌에서 보고...
# 3     양산시 동면 양산천 낙동강 고수부지에 위치한 가산 수변공원은 2012년 4대강 사업...
# 4     금원산 북쪽 골짜기 큰 바위굴에 새겨져 있는 마애불이다. 뒤의 돌계단을 오르면 바위...
# ...                                                 ...
# 1340  이곳은 김상례(金商禮)의 유적지(遺蹟址)이다. 당시 홍경래난(洪景來亂)의 여파로 속...
# 1341  백사장 길이 360m, 폭 30m의 아담한 해수욕장이다. 고운 모래사장과 남쪽 해변...
# 1342  예로부터 흰돌이 많아 백석산이라 불리던 곳에 흰돌메 공원이 조성되었다. 흰돌메 공원...
# ...

# %%
addr_gyeongnam = df_gyeongnam['addr1']
title_gyeongnam = df_gyeongnam['title']
mapxxy_gyeongnam = df_gyeongnam.loc[:,'mapx':'mapy']
image_gyeongnam = df_gyeongnam['firstimage']

gyeongnamDf = pd.concat([title_gyeongnam,addr_gyeongnam,mapxxy_gyeongnam,image_gyeongnam], axis=1)
gyeongnamDf
# Out:
#               title                      addr1            mapx           mapy  \
# 0     가고파 꼬부랑길 벽화마을  경상남도 창원시 마산합포구 성호서7길 15-8  128.5696552845  35.2077664004
# 1               가라산           경상남도 거제시 남부면 다대리  128.6303346514  34.7410502933
# 2             가뫼골마을       경상남도 진주시 명석면 관덕길 174  128.0324121006  35.2586565930
# 3              가배량성           경상남도 거제시 동부면 가배리  128.5722052958  34.7817585943
# 4            가산수변공원        경상남도 양산시 동면 가산리 799  129.0178748959  35.2950648080
# ...             ...                        ...             ...            ...
# 1340        흥부암(김해)        경상남도 김해시 전하로 269-74  128.8700563327  35.2263892341
# 1341          흰돌메공원       경상남도 창원시 진해구 남영로 280  128.7722960768  35.0993822404
# 1342          흰작살해변     경상남도 통영시 욕지면 욕지일주로 352  128.2658271909  34.6444934659
# 1343     3.15해양누리공원       경상남도 창원시 마산합포구 월남동1가  128.5640646750  35.1866103409
# 1344     LH 토지주택박물관            경상남도 진주시 충의로 19  128.1463098029  35.1776899504
#
# ...

# %%
gyeongnam_summary = gyeongnam_summary.drop(gyeongnam_summary[gyeongnam_summary['title'] == '내원사계곡'].index)
gyeongnam_summary = gyeongnam_summary.drop(gyeongnam_summary[gyeongnam_summary['title'] == '송호서원'].index)
gyeongnam_summary = gyeongnam_summary.drop(gyeongnam_summary[gyeongnam_summary['title'] == '신계서원'].index)

# %%
gyeongnamDf = gyeongnamDf.drop(gyeongnamDf[gyeongnamDf['title'] == '내원사계곡'].index)
gyeongnamDf = gyeongnamDf.drop(gyeongnamDf[gyeongnamDf['title'] == '송호서원'].index)
gyeongnamDf = gyeongnamDf.drop(gyeongnamDf[gyeongnamDf['title'] == '신계서원'].index)

# %%
print(gyeongnamDf['title'].value_counts())
print(gyeongnam_summary['title'].value_counts())
# Out:
# 가고파 꼬부랑길 벽화마을                            1
# 유학사(의령)                                  1
# 유동해변 (유동해수욕장)                            1
# 유근종사진가와 함께하는 진주사진여행(falling in Jinju)    1
# 위양지(양양지)                                 1
#                                         ..
# 미양서원                                     1
# 미숭산관광지                                   1
# 미숭산                                      1
# 미륵산(통영)                                  1
# LH 토지주택박물관                               1
# Name: title, Length: 1339, dtype: int64
# 가고파 꼬부랑길 벽화마을    1
# 거제 관광모노레일        1
# 거류산&거류산성         1
# 강주 해바라기 마을       1
# 강양향교             1
#                 ..
# 송전마을             1
# 송계사(거창)          1
# 속천항              1
# 소쿠리섬             1
# LH 토지주택박물관       1
# Name: title, Length: 1339, dtype: int64

# %%
gyeongnam_tour = pd.merge(gyeongnamDf,gyeongnam_summary, on='title', how='inner')
gyeongnam_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
gyeongnam_tour
# Out:
#               title                      addr1            mapx           mapy  \
# 0     가고파 꼬부랑길 벽화마을  경상남도 창원시 마산합포구 성호서7길 15-8  128.5696552845  35.2077664004
# 1               가라산           경상남도 거제시 남부면 다대리  128.6303346514  34.7410502933
# 2             가뫼골마을       경상남도 진주시 명석면 관덕길 174  128.0324121006  35.2586565930
# 3              가배량성           경상남도 거제시 동부면 가배리  128.5722052958  34.7817585943
# 4            가산수변공원        경상남도 양산시 동면 가산리 799  129.0178748959  35.2950648080
# ...             ...                        ...             ...            ...
# 1334        흥부암(김해)        경상남도 김해시 전하로 269-74  128.8700563327  35.2263892341
# 1335          흰돌메공원       경상남도 창원시 진해구 남영로 280  128.7722960768  35.0993822404
# 1336          흰작살해변     경상남도 통영시 욕지면 욕지일주로 352  128.2658271909  34.6444934659
# 1337     3.15해양누리공원       경상남도 창원시 마산합포구 월남동1가  128.5640646750  35.1866103409
# 1338     LH 토지주택박물관            경상남도 진주시 충의로 19  128.1463098029  35.1776899504
#
# ...

# %%
gyeongnam_tour.to_csv('경남관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 전북

# %%
jeonbuk = []
url_jeonbuk = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=37'
data_xml_jeonbuk = requests.get(url_jeonbuk).text
dictionary_jeonbuk = xmltodict.parse(data_xml_jeonbuk)
data_json_jeonbuk = json.loads(json.dumps(dictionary_jeonbuk) )
data_jeonbuk = data_json_jeonbuk['response']['body']['items']['item']
df_jeonbuk = pd.DataFrame(data_jeonbuk)
print(len(df_jeonbuk))
df_jeonbuk
# Out:
# 968
#                         addr1  addr2 areacode booktour cat1   cat2       cat3  \
# 0    전라북도 부안군 변산면 새만금로 447-27   None       37        0  A01  A0101  A01011400
# 1            전라북도 부안군 상서면 청림리   None       37        0  A01  A0101  A01010900
# 2          전라북도 남원시 운봉읍 비전길 7   None       37        0  A02  A0201  A02010500
# 3        전라북도 순창군 복흥면 하리길 160  (복흥면)       37        0  A02  A0201  A02010500
# 4          전라북도 남원시 운봉읍 가장길 4   None       37        0  A02  A0203  A02030100
# ..                        ...    ...      ...      ...  ...    ...        ...
# 963          전라북도 김제시 승반길 103   None       37        0  A02  A0201  A02010800
# 964    전라북도 남원시 인월면 인월리 산53-1   None       37        0  A01  A0101  A01010600
# 965        전라북도 고창군 흥덕면 동헌길 4  (흥덕면)       37        0  A02  A0201  A02010100
# 966              전라북도 임실군 임실읍   None       37        0  A02  A0201  A02010700
# 967        전라북도 완주군 내월길 92-58   None       37     None  A02  A0203  A02030400
#
# ...

# %%
# 상세설명 불러오기
jeonbuk_summary = pd.read_csv('전라북도overview.csv',encoding='utf-8')
jeonbuk_summary
# Out:
#      Unnamed: 0                 title  \
# 0             0                 가마소계곡
# 1             1  가왕 송흥록 박초월 생가(송홍록생가)
# 2             2            가인 김병로 생가터
# 3             3                  가장마을
# 4             4                  갈거계곡
# ..          ...                   ...
# 963         163                   회문산
# 964         164                  효충서원
# 965         165               후지리탑동석불
# 966         166                  흥성동헌
# 967         167                 3.1동산
#
#                                               overview
# 0    가마소의 형태로 가마솥 가마소란 이름이 붙여진 것 같고 변산 산중에서 교통이 제일 ...
# 1    가왕 송흥록 박초월 생가는 남원시 운봉읍 화수리 비전마을에 자리 잡고 있다. 비전마...
# 2    조선 중기의 도학자 하서 김인후 선생의 15대손인 가인 김병로 선생의 생가로 이곳에...
# 3    가장마을은 노치마을 오른쪽에 있는 덕산저수지 동쪽의 구릉 지대와 경계로 접하고 있다...
# 4    갈거계곡은 전북 진안군 운장산(1,126m)에 위치하며 연석산의 연동골, 운장산의 ...
# ..                                                 ...
# 963  회문산(830m)은 임실군, 순창군, 정읍시의 경계를 이루고 있고 산으로 회문봉, ...
# 964  효충서원은 임실군 임실읍에 위치하고 있는 서원으로 김복규, 김기종 부자의 효행을 기...
# ...

# %%
addr_jeonbuk = df_jeonbuk['addr1']
title_jeonbuk = df_jeonbuk['title']
mapxxy_jeonbuk = df_jeonbuk.loc[:,'mapx':'mapy']
image_jeonbuk = df_jeonbuk['firstimage']

jeonbukDf = pd.concat([title_jeonbuk,addr_jeonbuk,mapxxy_jeonbuk,image_jeonbuk], axis=1)
jeonbukDf
# Out:
#                     title                     addr1            mapx  \
# 0                    가력도항  전라북도 부안군 변산면 새만금로 447-27  126.5314023248
# 1                   가마소계곡          전라북도 부안군 상서면 청림리  126.5979680020
# 2    가왕 송흥록 박초월 생가(송홍록생가)        전라북도 남원시 운봉읍 비전길 7  127.5626899062
# 3              가인 김병로 생가터      전라북도 순창군 복흥면 하리길 160  126.9774224423
# 4                    가장마을        전라북도 남원시 운봉읍 가장길 4  127.5179339854
# ..                    ...                       ...             ...
# 963               흥복사(김제)          전라북도 김제시 승반길 103  126.9068023390
# 964              흥부골자연휴양림    전라북도 남원시 인월면 인월리 산53-1  127.5872436242
# 965                  흥성동헌        전라북도 고창군 흥덕면 동헌길 4  126.7001924599
# 966                 3.1동산              전라북도 임실군 임실읍  127.2814189685
# 967        (유) 복합문화공간 서리울        전라북도 완주군 내월길 92-58  127.1454845087
#
#               mapy                                         firstimage
# 0    35.7269248004                                               None
# ...

# %%
jeonbukDf = jeonbukDf.drop(jeonbukDf[jeonbukDf['title'] == '유천서원'].index)
jeonbukDf = jeonbukDf.drop(jeonbukDf[jeonbukDf['title'] == '화동서원'].index)
jeonbukDf = jeonbukDf.drop(jeonbukDf[jeonbukDf['title'] == '옥산서원'].index)

# %%
jeonbuk_summary = jeonbuk_summary.drop(jeonbuk_summary[jeonbuk_summary['title'] == '유천서원'].index)
jeonbuk_summary = jeonbuk_summary.drop(jeonbuk_summary[jeonbuk_summary['title'] == '화동서원'].index)
jeonbuk_summary = jeonbuk_summary.drop(jeonbuk_summary[jeonbuk_summary['title'] == '옥산서원'].index)

# %%
print(jeonbukDf['title'].value_counts())
print(jeonbuk_summary['title'].value_counts())
# Out:
# 가력도항                 1
# 인월담                  1
# 용추폭포(무주)             1
# 용호서원                 1
# 용화사(고창)              1
#                     ..
# 문수사(익산)              1
# 문창서원                 1
# 문태서, 박춘실 의병대장 전적비    1
# 문화살롱                 1
# (유) 복합문화공간 서리울       1
# Name: title, Length: 962, dtype: int64
# 가마소계곡                1
# 순창장류체험관              1
# 문수사(익산)              1
# 문창서원                 1
# 문태서, 박춘실 의병대장 전적비    1
#                     ..
# 완산칠봉(완산공원)           1
# 완주 고산 놀토피아           1
# 완주 인덕마을[농촌체험휴양마을]    1
# 완주상관편백숲              1
# 3.1동산                1
# Name: title, Length: 962, dtype: int64

# %%
jeonbuk_tour = pd.merge(jeonbukDf,jeonbuk_summary, on='title', how='inner')
jeonbuk_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
jeonbuk_tour
# Out:
#                     title                     addr1            mapx  \
# 0                    가력도항  전라북도 부안군 변산면 새만금로 447-27  126.5314023248
# 1                   가마소계곡          전라북도 부안군 상서면 청림리  126.5979680020
# 2    가왕 송흥록 박초월 생가(송홍록생가)        전라북도 남원시 운봉읍 비전길 7  127.5626899062
# 3              가인 김병로 생가터      전라북도 순창군 복흥면 하리길 160  126.9774224423
# 4                    가장마을        전라북도 남원시 운봉읍 가장길 4  127.5179339854
# ..                    ...                       ...             ...
# 957               흥복사(김제)          전라북도 김제시 승반길 103  126.9068023390
# 958              흥부골자연휴양림    전라북도 남원시 인월면 인월리 산53-1  127.5872436242
# 959                  흥성동헌        전라북도 고창군 흥덕면 동헌길 4  126.7001924599
# 960                 3.1동산              전라북도 임실군 임실읍  127.2814189685
# 961        (유) 복합문화공간 서리울        전라북도 완주군 내월길 92-58  127.1454845087
#
#               mapy                                         firstimage  \
# 0    35.7269248004                                               None
# ...

# %%
jeonbuk_tour.to_csv('전북관광지.csv',encoding='utf-8')

# %% [markdown]
# ## 전남

# %%
jeonnam = []
url_jeonnam = 'https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=Y1rUv22HCHPzXpYo2gQkFTWzmhTBj8gX96xMwF%2F1qGVx%2FM5vhmkKTgXYaq1c%2FWvQ%2B6siW4GNc3GLIRASRJZS%2Bw%3D%3D&numOfRows=1500&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=&listYN=Y&arrange=A&contentTypeId=12&areaCode=38'
data_xml_jeonnam = requests.get(url_jeonnam).text
dictionary_jeonnam = xmltodict.parse(data_xml_jeonnam)
data_json_jeonnam = json.loads(json.dumps(dictionary_jeonnam) )
data_jeonnam = data_json_jeonnam['response']['body']['items']['item']
df_jeonnam = pd.DataFrame(data_jeonnam)
print(len(df_jeonnam))
df_jeonnam
# Out:
# 1228
#                          addr1  addr2 areacode booktour cat1   cat2  \
# 0       전라남도 신안군 흑산면 가거도길 38-2  (흑산면)       38        0  A01  A0101
# 1       전라남도 진도군 고군면 신비의바닷길 47  (고군면)       38        0  A01  A0101
# 2          전라남도 담양군 용면 용소길 261   None       38        0  A01  A0101
# 3          전라남도 담양군 용면 용소길 261   None       38        0  A01  A0101
# 4        전라남도 영광군 홍농읍 가마미로 355   None       38        0  A01  A0101
# ...                        ...    ...      ...      ...  ...    ...
# 1223    전라남도 곡성군 오곡면 기차마을로 232   None       38        0  A02  A0202
# 1224       전라남도 무안군 해안로 313-56   None       38     None  A02  A0203
# 1225  전라남도 해남군 현산면 봉동길 232-118   None       38        0  A01  A0101
# 1226           전라남도 여수시 박람회길 1  (덕충동)       38        0  A02  A0205
# 1227       전라남도 영광군 영광읍 현암길 43   None       38        0  A04  A0401
#
#            cat3 contentid contenttypeid     createdtime  ...  \
# 0     A01011300    127480            12  20030905090000  ...
# ...

# %%
# 상세설명 불러오기
jeonnam_summary = pd.read_csv('전라남도overview.csv',encoding='utf-8')
jeonnam_summary
# Out:
#       Unnamed: 0        title  \
# 0              0         가계해변
# 1              1        가마골계곡
# 2              2      가마골생태공원
# 3              3      가마미해수욕장
# 4              4      가사동백숲해변
# ...          ...          ...
# 1223          23  흑산도 해상관광유람선
# 1224          24      흥국사(여수)
# 1225          25          흥덕사
# 1226          26     4est 수목원
# 1227          27       GB포유공방
#
#                                                overview
# 0     바닷물이 갈라지는 현대판 모세의 기적으로 유명한 회동국민관광지 내에 있는 해수욕장이...
# 1     가마골은 담양군 용면 용연리에 소재한 용추봉(523m)을  중심으로 사방 4km에 ...
# 2     담양의 가장 북쪽에 자리하고 있는 가마골은 그 일대에 그릇을 굽는 가마터가 많다고 ...
# 3     영광읍 서쪽 24km 거리에 위치한 해수욕장으로 본격적으로 개장된 것은 1925년의...
# 4     약산면의 남쪽 끝자락에 위치한 가사동백숲해변은 수백 년 된 동백나무 수 백 그루와 ...
# ...                                                 ...
# 1223  크고 작은 유인도 11개, 무인도 89개의 총 백 여개의 섬으로 이루어진 대규모 군...
# 1224  흥국사란 이름에서 알 수 있듯이 ‘국가가 흥하면 절도 흥한다’ 는 나라의 융성을 기...
# 1225  흥덕사(興德寺)는 고흥군 동강면 장덕리 산 10번지 첨산(尖山)에 자리한 대한불교태...
# ...

# %%
addr_jeonnam = df_jeonnam['addr1']
title_jeonnam = df_jeonnam['title']
mapxxy_jeonnam = df_jeonnam.loc[:,'mapx':'mapy']
image_jeonnam = df_jeonnam['firstimage']

jeonnamDf = pd.concat([title_jeonnam,addr_jeonnam,mapxxy_jeonnam,image_jeonnam], axis=1)
jeonnamDf
# Out:
#              title                     addr1            mapx           mapy  \
# 0        가거도(소흑산도)    전라남도 신안군 흑산면 가거도길 38-2  125.1125145360  34.0740166502
# 1             가계해변    전라남도 진도군 고군면 신비의바닷길 47  126.3547412438  34.4354594945
# 2            가마골계곡       전라남도 담양군 용면 용소길 261  127.0227046757  35.4451873670
# 3          가마골생태공원       전라남도 담양군 용면 용소길 261  127.0227796727  35.4450484951
# 4          가마미해수욕장     전라남도 영광군 홍농읍 가마미로 355  126.4090769892  35.3997293920
# ...            ...                       ...             ...            ...
# 1223      1004장미공원    전라남도 곡성군 오곡면 기차마을로 232  127.3082114814  35.2776556637
# 1224            3S       전라남도 무안군 해안로 313-56  126.3963787890  34.9189919045
# 1225      4est 수목원  전라남도 해남군 현산면 봉동길 232-118  126.5955113195  34.4532475345
# 1226  BIG-O쇼 (빅오쇼)           전라남도 여수시 박람회길 1  127.7465197232  34.7522251119
# 1227        GB포유공방       전라남도 영광군 영광읍 현암길 43  126.5094683447  35.2764339291
#
#                                              firstimage
# ...

# %%
jeonnam_summary = jeonnam_summary.drop(jeonnam_summary[jeonnam_summary['title'] == '장도'].index)
jeonnamDf = jeonnamDf.drop(jeonnamDf[jeonnamDf['title'] == '장도'].index)

# %%
print(jeonnamDf['title'].value_counts())
print(jeonnam_summary['title'].value_counts())
# Out:
# 가거도(소흑산도)             1
# 외달도                   1
# 용바위터                  1
# 용문사(여수)               1
# 용두마을                  1
#                      ..
# 무안 유교리고가              1
# 무안 용월리 백로와 왜가리 번식지    1
# 무안 식영정                1
# 무안 백련흑콩마을(두레미마을)      1
# GB포유공방                1
# Name: title, Length: 1226, dtype: int64
# 가계해변                  1
# 곡수서원                  1
# 구 보성여관                1
# 광양만권 경제자유구역 홍보관       1
# 광양 윤동주 유고보존 정병욱 가옥    1
#                      ..
# 순솝 (더감동협동조합)          1
# 수한마을                  1
# 수문항                   1
# 수만리생태숲공원              1
# GB포유공방                1
# Name: title, Length: 1226, dtype: int64

# %%
jeonnam_tour = pd.merge(jeonnamDf,jeonnam_summary, on='title', how='inner')
jeonnam_tour.drop(["Unnamed: 0"],axis=1,inplace=True)
jeonnam_tour
# Out:
#              title                     addr1            mapx           mapy  \
# 0        가거도(소흑산도)    전라남도 신안군 흑산면 가거도길 38-2  125.1125145360  34.0740166502
# 1             가계해변    전라남도 진도군 고군면 신비의바닷길 47  126.3547412438  34.4354594945
# 2            가마골계곡       전라남도 담양군 용면 용소길 261  127.0227046757  35.4451873670
# 3          가마골생태공원       전라남도 담양군 용면 용소길 261  127.0227796727  35.4450484951
# 4          가마미해수욕장     전라남도 영광군 홍농읍 가마미로 355  126.4090769892  35.3997293920
# ...            ...                       ...             ...            ...
# 1221      1004장미공원    전라남도 곡성군 오곡면 기차마을로 232  127.3082114814  35.2776556637
# 1222            3S       전라남도 무안군 해안로 313-56  126.3963787890  34.9189919045
# 1223      4est 수목원  전라남도 해남군 현산면 봉동길 232-118  126.5955113195  34.4532475345
# 1224  BIG-O쇼 (빅오쇼)           전라남도 여수시 박람회길 1  127.7465197232  34.7522251119
# 1225        GB포유공방       전라남도 영광군 영광읍 현암길 43  126.5094683447  35.2764339291
#
# ...

# %%
jeonnam_tour.to_csv('전남관광지.csv',encoding='utf-8')
